# %%
import numpy as np
import pandas as pd
from konlpy.tag import Mecab
from tqdm import tqdm
from collections import Counter
import itertools # 2차원 배열 1차원 배열로
from sklearn.feature_extraction.text import TfidfVectorizer
import os #폴더 이름 가져오기

class Preprocessor:
    def __init__(self, filepath, stopwords_file):
        self.filepath = filepath
        self.stopwords_file = stopwords_file
        self.stopwords = self.load_stopwords()
        self.file_list = self.choice_file()
        self.files = self.load_files()

    def load_stopwords(self):
        with open(self.stopwords_file, encoding='utf-8') as f:
            stopwords = [line.strip() for line in f]
        return stopwords

    def choice_file(self):
        file_list = os.listdir(self.filepath)
        cnt=0
        for i in file_list:
            i=self.filepath+"/"+i
            file_list[cnt]=i
            cnt+=1
        return file_list

    def load_files(self):
        files=[]
        for i in self.file_list:
            try:
                df=pd.read_csv(i,encoding="UTF-8") # 크롤링한 파일 가져오기
                files.append(df)
            except:
                pass #.ipynb_checkpoints 파일때문
        return self.delete(files)

    def delete(self, files):
        result=[]
        for df in files:
            df=df.replace("- dc official App","") # 글 내용없을때 들어가는 "- dc official App" 대체
            df=df.fillna('') # 결측치 제거
            df['data']=df['title']+ " " +df['content'] # 제목+내용을 하나로 합쳐서 'data'로 저장 
            del df['title'],df['content'],df['no'] # 제목,내용,글번호 삭제
            data=df['data']
            result.append(df)
        return result

    def data_processing(self):
        for file in self.files:
            file['data']=file['data'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규화
            file['data']=file['data'].str.replace('^ +', "") # 공백은 empty값으로 변경
            file['data'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
            file['data'].dropna(how='any',inplace=True) # Null 값 제거

    def data_processing_stopword(self):
        m=Mecab()
        result=[]
        print("모든 파일 불용어 제거중...")
        for file in self.files:
            rs=[]
            for i in tqdm(file['data']):
                tokenized_sentence =m.morphs(str(i))
                stopwords_removed_sentence=[word for word in tokenized_sentence if not word in self.stopwords]
                rs.append(stopwords_removed_sentence)
            result.append(rs)
        return self.remove_one_word(result)

    def remove_one_word(self, result):
        one_word_remove=[]
        for res in result:
            temp=[]
            for word in res:
                tmp=[]
                for i in word:
                    if len(i)>1:
                        tmp.append(i)
                temp.append(tmp)
            one_word_remove.append(temp)
        print("한 글자 제외 완료")
        return self.filter_pos(one_word_remove)
    
    def filter_pos(self, one_word_remove):
        print("Mecab 실행중...")
        result=[]
        m=Mecab()
        for onefile in tqdm(one_word_remove):
            rs=[]
            for word in onefile:
                tmp=[]
                for i in word:
                    if m.pos(i)[0][1]=='NNG' or m.pos(i)[0][1]=='NNB' or m.pos(i)[0][1]=='NNBC' or m.pos(i)[0][1]=='NR' or m.pos(i)[0][1]=='NP' or m.pos(i)[0][1]=='VX' or m.pos(i)[0][1]=='VCP' or m.pos(i)[0][1]=='VCN' or m.pos(i)[0][1]=='MAJ'or m.pos(i)[0][1]=='VV' or m.pos(i)[0][1]=='VA' or m.pos(i)[0][1]=='MMG':
                        tmp.append(m.pos(i)[0][0])
                rs.append(tmp)
            result.append(rs)
        return result

# %%
import numpy as np

# 데이터가 저장된 폴더 경로
filepath = '/Users/home/jp/1일전일봉고점'

stopwords_file=('/Users/home/jp/stopwords.txt')

# 클래스 인스턴스화
preprocessor = Preprocessor(filepath, stopwords_file)

# 데이터 전처리
preprocessor.data_processing()

# 결과
result=preprocessor.data_processing_stopword()
# Out:
# /var/folders/mf/zx0plt5520l4g1dfsl85d0gm0000gn/T/ipykernel_67572/2903835059.py:55: FutureWarning: The default value of regex will change from True to False in a future version.
#   file['data']=file['data'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규화
# /var/folders/mf/zx0plt5520l4g1dfsl85d0gm0000gn/T/ipykernel_67572/2903835059.py:56: FutureWarning: The default value of regex will change from True to False in a future version.
#   file['data']=file['data'].str.replace('^ +', "") # 공백은 empty값으로 변경
# 불용어 제거중...
# 100%|████████████████████████████████████| 5691/5691 [00:00<00:00, 16754.11it/s]
# 100%|████████████████████████████████████| 4796/4796 [00:00<00:00, 20116.77it/s]
# 100%|████████████████████████████████████| 2760/2760 [00:00<00:00, 18634.03it/s]
# 100%|██████████████████████████████████████| 994/994 [00:00<00:00, 15893.51it/s]
# 100%|████████████████████████████████████| 5044/5044 [00:00<00:00, 14949.05it/s]
# 100%|████████████████████████████████████| 4737/4737 [00:00<00:00, 17475.44it/s]
# 100%|████████████████████████████████████| 4882/4882 [00:00<00:00, 17116.32it/s]
# 100%|██████████████████████████████████| 10535/10535 [00:00<00:00, 18235.22it/s]
# 100%|████████████████████████████████████| 2794/2794 [00:00<00:00, 18562.95it/s]
# 100%|████████████████████████████████████| 1505/1505 [00:00<00:00, 14644.75it/s]
# 100%|████████████████████████████████████| 2609/2609 [00:00<00:00, 17527.60it/s]
# 한 글자 제외 완료
# Mecab 실행중...
# 100%|███████████████████████████████████████████| 11/11 [00:09<00:00,  1.11it/s]

# %%
result
# Out:
# [[['무섭'],
#   ['보너스', '보너스', '올리', '근데', '차트', '미치'],
#   [],
#   ['발표', '어치', '여여'],
#   ['천만'],
#   ['오늘', '급등', '대장', '누구'],
#   [],
#   ['시발'],
#   ['아무'],
#   [],
#   ['기회'],
#   ['메타', '자연재해'],
#   ['조금', '슈팅', '손절'],
#   [],
#   ['속보', '음전자', '망토', '구입'],
#   ['시아', '시아', '준수', '탑승'],
#   ['오늘'],
#   [],
#   ['멸망'],
#   ['출발'],
#   ['시바', '발표'],
#   ['척하'],
#   ['발아'],
#   ['제발'],
#   ['블록'],
#   ['다음', '기후', '코인', '다음', '보'],
#   ['상장', '상장', '지갑', '연동', '상장'],
#   ['썸씽'],
#   ['양반', '출발', '부자'],
#   ['블록'],
#   ['코어', '운지'],
#   ['제단', '실시간', '발표', '영상'],
#   ['썸씽'],
#   ['제발'],
#   ['개자'],
#   ['정조대', '무엇', '절대', '뚫리', '강철', '정조대'],
#   ['세력', '코인', '이동', '폭락'],
#   ['버러지', '코인'],
#   ['폭풍', '저그'],
#   ['엑스', '기사', '고마', '역시', '내촉', '근데'],
#   ['블록', '고점', '이거'],
#   ['쿼크', '기후', '변화', '지리', '다음'],
#   ['시즌'],
#   [],
#   ['경주마', '새끼', '필독', '나락'],
#   ['쿼크'],
#   ['블록', '고점'],
#   [],
#   [],
#   ['방구', '손절', '가망'],
#   ['파워', '대가리', '뜨겁'],
#   ['개추'],
#   ['사라', '개저', '선동'],
#   ['세력', '악물', '개미', '털기', '발표', '나기', '이렇'],
#   [],
#   ['블록'],
#   ['쿼크', '어제', '계속', '가지'],
#   ['고맙', '덕분'],
#   [],
#   ['급속', '보라', '빙시'],
#   ['방구', '지금', '손절', '인생', '망하'],
#   ['어우', '병신'],
#   ['결국'],
#   ['시티', '은행', '시티', '은행'],
#   ['최저'],
#   ['홍금', '보', '정확', '오늘', '경주마', '쿼크', '체인', '엑스'],
#   ['병신', '영어', '발표', '모르'],
#   ['제발'],
#   [],
#   ['장군', '청룡', '언월'],
#   ['추가'],
#   ['발표', '발표'],
#   [],
#   ['사실', '코인', '털리', '망상', '싸지르', '장애', '개추'],
#   ['개미'],
#   ['장군', '의심'],
#   ['타자'],
#   [],
#   ['장군'],
#   ['블록', '제자리'],
#   ['장군'],
#   ['방구', '매수', '완료', '방금', '오', '마다', '추가'],
#   ['모르', '평단'],
#   ['속보'],
#   ['지랄'],
#   ['세근', '세근', '청산'],
#   ['박멸', '기분', '개추'],
#   ['평단', '최대', '방금'],
#   ['비트', '마이너스', '설명'],
#   [],
#   [],
#   ['장군', '발표'],
#   ['음전자', '망토', '구입'],
#   ['모스', '이거', '지폐', '준비'],
#   ['슈팅'],
#   ['고맙', '역시'],
#   ['승리', '오너', '개추'],
#   ['방송', '중계'],
#   ['개미', '병신', '새끼', '평생', '이유'],
#   ['오늘', '아침', '준비'],
#   ['실시간', '발표', '영상', '좌표'],
#   ['가짜', '쿼크', '호구', '읍지'],
#   ['한참', '저점'],
#   ['수상'],
#   ['마지막', '개미', '털기', '새끼', '개추'],
#   ['세력', '시발'],
#   ['손절'],
#   ['야지'],
#   ['블록', '설거지', '당한', '호구'],
#   ['코스모스', '불장', '시대'],
#   ['쿼크', '체인', '기사', '기사', '보'],
#   ['음전', '분전'],
#   ['발표', '근본', '코인'],
#   ['마지막', '설거지', '완벽', '다수', '발생'],
#   ['제로', '엑스', '병신', '분도', '상병', '코인', '처음', '보네'],
#   ['발광', '등신', '새끼', '그렇', '홀더', '옹호'],
#   ['심상'],
#   [],
#   ['탑승'],
#   ['블록', '기사', '발련', '짱돌', '객사', '띄', '사지'],
#   ['응디', '엑스', '무빙', '살벌'],
#   ['병신', '계속', '떨어지'],
#   ['협업'],
#   ['시즌'],
#   ['호재', '출발'],
#   [],
#   ['본인', '개병', '쿼크', '손절'],
#   ['기사'],
#   ['모가지', '출발'],
#   ['작년', '엑스', '탈출', '시발'],
#   ['페이크'],
#   ['근데', '코인', '호재', '상관', '주식'],
#   ['발표'],
#   ['쿼크', '체인', '맹수', '개추'],
#   ['설거지', '진심', '코인', '설거지'],
#   ['모스', '거래'],
#   [],
#   ['잔인', '잔인', '빨아먹'],
#   ['블록', '유쾌', '음전'],
#   [],
#   ['시일',
#    '폭',
#    '코인',
#    '어제',
#    '오늘',
#    '음전',
#    '양전',
#    '일봉',
#    '주봉',
#    '작년',
#    '이맘때',
#    '이후',
#    '매집',
#    '극한',
#    '저점',
#    '미래',
#    '가치',
#    '협업',
#    '주일',
#    '양전',
#    '패턴',
#    '코인',
#    '좆같',
#    '오늘',
#    '하루',
#    '사랑',
#    '행복',
#    '오늘',
#    '하나',
#    '마무리',
#    '하루',
#    '이상'],
#   ['실시간', '해석'],
#   ['지랄', '병신', '금마'],
#   [],
#   ['수직', '승중'],
#   ['아무'],
#   ['엑스', '설거지', '역시', '엑스', '설거지', '코인'],
#   ['미터', '호재', '차트', '몇일', '저렇', '대장'],
#   ['방금', '이거', '나', '나', '나'],
#   ['복구'],
#   ['요즘', '근데', '시경', '주마'],
#   ['살인', '충동'],
#   ['꼬', '개추'],
#   ['몇일', '고립', '탈출', '고맙', '이'],
#   ['코인'],
#   ['고민', '중위', '물대', '저번'],
#   ['유쾌', '음전', '유쾌', '통쾌'],
#   ['쿼크', '체인'],
#   ['쿼크', '토막', '다만', '개추'],
#   ['수익', '프로', '이상', '욕심', '홀더'],
#   ['쿼크', '운지'],
#   ['쿼크'],
#   ['방구', '재밌'],
#   ['쿼크', '체인', '파멸', '운지'],
#   ['쿼크', '체인', '시작', '도손', '떨리'],
#   ['쿼크', '지랄', '병신'],
#   ['사람', '구조'],
#   ['세력', '의미', '역대'],
#   ['쿼크', '원간'],
#   ['발표', '협력', '폭'],
#   ['설거지'],
#   ['죽', '사람', '꽃놀이', '사람', '좆같'],
#   ['침팬지', '차트', '완성', '어제', '차트'],
#   ['느', '평단', '흑우'],
#   ['오늘', '추비', '개추', '시벌'],
#   ['저점'],
#   ['생방'],
#   ['쿼크', '호구', '업제'],
#   ['야심', '불장', '손실', '개추'],
#   ['세력'],
#   ['블록', '어제', '손절', '평단', '보'],
#   ['가스', '거지', '코인'],
#   ['쿼크', '느낌'],
#   ['아크', '아야'],
#   ['오늘',
#    '라이',
#    '어제',
#    '소나',
#    '오늘',
#    '설거지',
#    '내일',
#    '메이',
#    '저장',
#    '마음',
#    '저장',
#    '어제',
#    '자기',
#    '마냥',
#    '느낌',
#    '호구'],
#   [],
#   ['대호황', '금관', '망충', '피눈물'],
#   ['킬로미터', '거래량', '역시', '오늘', '양봉', '출발', '차트', '오랜만', '이후'],
#   ['아침', '손가락', '웃기'],
#   ['일선'],
#   ['멍청이', '지금', '발표', '에너지', '얘기', '작년', '툭툭이', '당한', '기억'],
#   ['파악', '파악'],
#   ['방구', '시바'],
#   ['웃기', '신규', '유입', '보'],
#   ['오늘', '어제', '복구', '기모'],
#   ['아무거', '붙이', '메타', '등쳐먹', '빼먹', '궁리', '새끼', '그래서', '진실'],
#   [],
#   ['쿼크', '구조', '제발'],
#   ['썸씽', '홀더', '하나'],
#   ['쿼크', '석우', '맛있'],
#   ['코인', '기분'],
#   ['낚시', '아침', '프로'],
#   ['준비', '하나'],
#   ['코인', '동호회', '세력', '흐리', '분만', '조심', '조막손', '동호회'],
#   ['청산', '유쾌', '열차', '출발'],
#   ['코인'],
#   ['하농', '무지', '매수', '이거', '한참', '남음'],
#   ['방금', '개떡', '개지'],
#   ['장이', '연달', '아서', '인지'],
#   ['오늘', '하루', '매수', '설거지', '시발', '무빙'],
#   ['아크'],
#   ['본인', '호재', '모시', '사라'],
#   ['승장', '추격', '매수', '흑우', '업제'],
#   ['인증', '바라', '인증'],
#   ['발련', '제발'],
#   ['줄때', '개추'],
#   ['잔인', '빨아먹'],
#   [],
#   ['대호황', '금관', '망충', '피눈물'],
#   ['탑승', '지금', '추세'],
#   ['오늘', '비트'],
#   ['다행', '불나방'],
#   [],
#   ['발표',
#    '시발',
#    '어디',
#    '같',
#    '소리',
#    '사실',
#    '확인',
#    '대체',
#    '발표',
#    '약속',
#    '버',
#    '그래서',
#    '지금',
#    '어디',
#    '발표'],
#   ['그때', '사도', '지금', '행복', '회로'],
#   ['욕심'],
#   ['호재', '역시'],
#   ['무지', '무지', '리미터', '탑승', '올리', '탑승', '거래량', '바닥', '바닥', '손절', '노리', '야지'],
#   ['모스', '기회', '지폐'],
#   ['호황', '금관', '망충', '오열'],
#   ['발표', '어디', '검색'],
#   ['엑스', '활좀'],
#   ['코인', '소개팅', '생각', '호감', '매일', '손실'],
#   ['가능',
#    '기사',
#    '아무',
#    '제일',
#    '개미',
#    '가격',
#    '심리',
#    '압박',
#    '세력',
#    '남짓',
#    '한방',
#    '처',
#    '사람'],
#   ['프로', '불기둥', '예열', '오늘'],
#   ['살짝', '기대', '물량', '계속', '넘'],
#   ['메타', '기사', '물량', '진고', '반복', '개자'],
#   ['시작', '현물', '시작', '알리', '쿼크', '체인', '축포', '소이'],
#   ['불장'],
#   ['버프', '매집'],
#   ['도지', '리언', '승리자', '개추'],
#   ['발표'],
#   ['오늘', '코인', '역대', '폭락', '오후'],
#   ['외치', '호구', '특징'],
#   ['하나'],
#   ['다음', '불장', '다음', '다음', '주말', '관망', '지금', '추세', '여서', '탑승', '이거'],
#   ['대박', '발표', '파트너'],
#   ['아디오스'],
#   ['그래서', '발표', '오늘', '아침', '최저', '이득', '한데'],
#   ['역시', '엑스', '악질', '기스', '코인'],
#   ['병신', '꼬', '개추'],
#   ['오늘', '준비', '버스', '출발', '예정'],
#   ['장군'],
#   ['손절', '그때'],
#   ['코인', '개소', '리임', '동영상', '영어'],
#   ['어제'],
#   ['양전'],
#   ['쿼크'],
#   [],
#   ['제하'],
#   ['불장', '금관', '망충', '오열'],
#   ['공개', '오예'],
#   ['방구', '마지막', '설거지', '소리', '망고'],
#   ['오늘', '일정', '새끼', '개추'],
#   ['사라', '개보'],
#   ['꼬', '개추'],
#   ['비트', '빠', '무섭'],
#   ['코인', '영어', '짜증'],
#   ['시야', '꽃길'],
#   ['웃기'],
#   ['발표', '따구', '강당', '아서', '그리고', '저녁', '저거', '발표'],
#   ['산거', '설거지', '개추'],
#   ['경주마', '실패', '개추'],
#   ['일주일', '이후'],
#   [],
#   [],
#   ['새끼', '나락', '과학', '어제', '승장', '새기', '순식간', '나락가', '과학', '마렵'],
#   ['이번', '사람'],
#   ['무비', '블록', '시간', '안전', '최고', '코인'],
#   ['점마', '저거'],
#   ['속보'],
#   ['일요일', '의미', '방법', '반지', '제왕', '시리즈', '시리즈', '슬램', '덩크', '시리즈'],
#   ['야무지', '개추'],
#   ['현재', '분임', '발표'],
#   ['코인',
#    '왕자',
#    '가지',
#    '가지',
#    '성공',
#    '도망',
#    '그렇',
#    '다면',
#    '망가',
#    '트리',
#    '소중',
#    '생각',
#    '특별',
#    '생각',
#    '생각',
#    '하나',
#    '때문',
#    '사람',
#    '지켜보',
#    '감시',
#    '주변인',
#    '섭외',
#    '하나',
#    '때문',
#    '막대',
#    '막대',
#    '인력',
#    '소비',
#    '가치',
#    '사람',
#    '자부심',
#    '코인',
#    '왕자'],
#   ['협업'],
#   ['흑우', '설마'],
#   ['어디', '설마', '손절'],
#   [],
#   ['엑스'],
#   ['투자', '개떡', '상각', '보임'],
#   ['메타', '새끼', '발련'],
#   [],
#   ['방구', '협업', '설명'],
#   ['빠르', '빠르'],
#   ['거래', '대금', '상위'],
#   ['일봉'],
#   ['휴먼'],
#   ['그럼', '그렇'],
#   ['메타', '세력', '매수', '시발'],
#   ['질문'],
#   ['오열', '그렇', '찬양', '결국'],
#   ['모스', '흑우', '거래', '개미', '려고', '무빙', '흑우', '인증'],
#   [],
#   ['오늘'],
#   ['일봉', '계속', '양봉'],
#   ['발표', '사전', '인터뷰', '발표'],
#   ['매수'],
#   ['병신', '요약'],
#   ['협업', '발표', '전이'],
#   [],
#   ['양전'],
#   [],
#   ['출발'],
#   ['방송', '그거'],
#   ['발표', '시시', '자위'],
#   ['비트', '루나'],
#   ['구조대'],
#   ['토익', '방송', '해석', '해', '방구'],
#   ['격리', '일차', '번한'],
#   ['쿼크', '하', '느낌'],
#   ['발표', '시작', '발표'],
#   ['매도', '물량', '얼마'],
#   ['나중', '원망', '마라'],
#   ['일임', '차트'],
#   [],
#   ['고소'],
#   ['왁스', '자위'],
#   ['친애', '아파트'],
#   [],
#   ['알리', '수고'],
#   ['엑스', '끝', '사람'],
#   ['백화점'],
#   ['바알'],
#   ['쿼크', '추천'],
#   ['쿼크'],
#   ['코인', '분산', '투자', '이것', '떨어지', '치'],
#   ['응디', '시티', '응디', '응디', '응디', '응디'],
#   ['한방'],
#   ['발표', '계정', '정지', '방송', '중단'],
#   ['협업', '대박', '근데'],
#   ['사전', '인터뷰', '시간', '발표'],
#   ['정지', '시발'],
#   [],
#   ['시발', '정지', '코인', '처음'],
#   ['발표', '시작', '예전'],
#   ['기사', '악질', '소문'],
#   ['메타', '허매', '수벽', '보소', '저놈', '마음'],
#   ['불장', '이거', '문제'],
#   ['정지', '공식', '사이트', '링크', '채널'],
#   [],
#   ['미터', '도랏', '도랏', '저세상', '차트', '일봉', '시발', '거래량'],
#   ['석봉', '토스트', '협업', '프로'],
#   ['아들', '학원', '우리', '집안', '생활비', '가정', '평화'],
#   ['병신', '보임', '이거', '설명'],
#   [],
#   ['주말', '코인', '개추'],
#   ['단원'],
#   ['방송', '정리', '사장', '새끼', '계정', '정지'],
#   ['발표', '그래서'],
#   ['지금'],
#   ['아래', '흔들리', '운전', '무섭'],
#   ['모스', '목표', '이거', '매집', '놓', '후회'],
#   ['순대', '곱창', '파트너'],
#   ['장군', '출발', '신', '화성'],
#   [],
#   ['발표', '대운', '지함'],
#   ['차트', '차트', '천국', '계단', '지대'],
#   ['장대', '양봉', '시작'],
#   ['큰일'],
#   ['방구', '직전', '배사'],
#   ['오늘', '작년', '수익', '사람', '하', '손해', '손절'],
#   ['매수'],
#   ['차이'],
#   [],
#   ['협업', '정신', '현실'],
#   [],
#   ['시바', '으'],
#   ['탑승', '완료', '탑승', '완료', '국행', '침팬지', '모르', '흑우', '차트'],
#   ['바라'],
#   ['내용'],
#   [],
#   ['떨어지'],
#   ['가스', '코인', '쓰레기'],
#   ['황리', '시기', '질투', '개추'],
#   ['사람', '실시간', '부니'],
#   ['찬양', '보', '정신병자', '인정', '개추', '식사', '세요'],
#   ['잔인', '설거지', '마지막', '개미', '털어먹', '잔인', '구만'],
#   ['전한',
#    '종목',
#    '추천',
#    '무비',
#    '블록',
#    '시간',
#    '박스',
#    '무한',
#    '횡보',
#    '후반',
#    '중반',
#    '매도',
#    '무한',
#    '복사',
#    '중임',
#    '안정',
#    '무비',
#    '거래소',
#    '주작',
#    '코인',
#    '가능',
#    '며칠',
#    '개꿀',
#    '중반',
#    '시바',
#    '생각',
#    '필요',
#    '절대'],
#   ['발표', '맞음'],
#   ['무비', '블록', '구조대'],
#   ['계속', '지금', '조금'],
#   ['손실', '가능'],
#   ['시드'],
#   ['협업', '루머', '어디'],
#   ['사람',
#    '나락',
#    '진심',
#    '어제',
#    '승장',
#    '새기',
#    '순식간',
#    '나락가',
#    '과학',
#    '마렵',
#    '손절',
#    '절대',
#    '발련'],
#   ['출발'],
#   ['심상', '심상'],
#   ['메타', '움보', '작년', '블록', '지랄'],
#   ['운지'],
#   ['무지', '성매매', '무지', '성매매', '요즘', '무지', '모르', '흑우', '장가', '추세'],
#   ['모스', '코인', '세력', '움직이', '살벌', '사라지', '반복'],
#   [],
#   ['협업', '가야지', '약하'],
#   ['쿼크', '폭락', '속도', '발아'],
#   ['점마', '저거'],
#   ['대상', '승장', '준비'],
#   ['오너', '대부분', '절반', '절반', '홀드', '루나', '거하', '열등감', '병신'],
#   ['보라', '사면', '생기', '사면', '사면', '얼굴', '보라색'],
#   ['쿼크', '개지'],
#   ['여자', '준비', '목욕', '시간', '출발'],
#   ['쿼크'],
#   ['매수', '호재', '발표', '후애'],
#   ['쿼크'],
#   ['장대', '양봉가', '장대', '양봉가', '매물', '하나', '구만'],
#   ['발련'],
#   ['카타', '쿼크', '체인'],
#   ['쿼크', '웃기'],
#   ['쿼크', '사라지', '무섭'],
#   ['쿼크'],
#   ['시발', '라라'],
#   ['쿼크', '아프'],
#   ['쿼크', '설거지', '야무지'],
#   ['매수', '고고'],
#   ['요즘', '돈복', '사장'],
#   ['쿼크'],
#   ['자야', '엽전'],
#   ['쿼크'],
#   ['오늘', '이거', '오늘', '이거', '추세', '아서', '탑승', '완료', '차트', '천국', '계단'],
#   ['이거'],
#   ['개호', '구새', '반대', '나락', '현금'],
#   ['쿼크', '개꿀'],
#   ['계속', '시경', '주마', '관망', '추천', '자추'],
#   ['쓰러지'],
#   ['벽력', '일섬', '웃기'],
#   ['모스', '주담', '박아', '대기', '목표', '지폐'],
#   ['설거지'],
#   ['사기', '방송', '저능아'],
#   ['오늘', '세력', '개미'],
#   ['조정', '무섭'],
#   ['오늘', '마다', '이렇', '조루', '불장'],
#   ['눈물', '실중', '개추'],
#   ['셀로', '역시', '패닉', '사면'],
#   ['저점', '노리'],
#   ['비트', '석우', '투자자', '보호', '비트'],
#   ['청산'],
#   ['설거지', '당한', '이거', '환불'],
#   ['도지', '코인'],
#   ['아서',
#    '오늘',
#    '바닥',
#    '지하',
#    '바닥',
#    '오늘',
#    '하루',
#    '코인',
#    '아서',
#    '우리',
#    '신경',
#    '인지',
#    '아서'],
#   ['난리', '안달', '바닥', '아서', '이거'],
#   ['설거지', '하락'],
#   ['어디', '오', '호재', '상승'],
#   ['오'],
#   ['쿼크', '속도'],
#   ['쿼크', '시발'],
#   ['웃음', '조루'],
#   ['지금', '가격', '다음'],
#   ['쿼크'],
#   ['사기', '이유', '얼굴', '비사', '기면', '죽임'],
#   ['오늘', '느글거리', '개추'],
#   ['쿼크', '세력', '생각', '요새', '보통', '횡보', '기다리'],
#   ['오늘', '아침', '자신', '개추', '수면제', '처먹'],
#   [],
#   ['괜찮'],
#   ['원간', '오늘', '원간', '수익', '실현', '내일', '매장', '야지', '차트', '국행'],
#   ['아침', '쿼크', '벽력', '일섬', '방금', '로랑', '쿼크', '시장', '천만', '공짜', '생김'],
#   ['본인', '종목', '고통', '개추'],
#   ['어제', '쿼크', '체인', '사라'],
#   ['장꼬', '라지', '바라', '설거지', '뿐', '세력', '활개'],
#   [],
#   ['쿼크', '틈새시장', '분만', '기분', '조타'],
#   ['천기누설', '지금', '클럽', '댓글', '여론', '그럼', '오히려', '오', '의미', '당장', '별점'],
#   ['이거', '사라', '이거', '응원', '물대', '일봉', '차트', '매물', '천국', '계단'],
#   ['점마', '저거'],
#   ['오늘', '설거지', '당하', '척하', '고꾸라지'],
#   ['방송', '아깝', '생각', '마구', '마구'],
#   ['오후', '귀신', '오', '개미', '털기', '채소'],
#   ['설마', '이나', '만큼', '생각'],
#   ['장사', '접자'],
#   ['요즘', '드림'],
#   ['바알'],
#   ['도지', '소리', '요란', '깡통', '코인'],
#   ['평단', '근데', '사실', '발표', '아래', '떨어지', '지금', '발표'],
#   ['재조명', '가능'],
#   ['어제', '오늘', '주인공', '메타', '어제', '점심', '고점', '프로', '수익'],
#   ['쿼크', '체인', '차트', '분석', '불나방', '필독', '병신', '분석', '시간', '시장'],
#   ['불장', '비트', '도미', '지금', '오후', '올리', '꼬라지', '이상', '모르', '흑우'],
#   ['쿼크', '이거', '가망', '기사', '발련', '진마'],
#   ['새기', '개추'],
#   ['설거지', '재밌', '개추'],
#   ['가지', '아서', '개추'],
#   ['오늘', '불장', '와이프'],
#   ['작년',
#    '이맘때',
#    '코인',
#    '무지',
#    '그때',
#    '막판',
#    '코인',
#    '리퍼',
#    '무비',
#    '요즘',
#    '꼬라지',
#    '그때',
#    '똑같',
#    '시작'],
#   ['좆같', '아서', '이렇'],
#   ['메이', '저장', '바뀌', '준비'],
#   ['친구'],
#   ['오늘', '내일', '통틀', '이거', '사라', '지금', '성중', '차트', '추세', '지금', '요거'],
#   ['대광', '삼위일체'],
#   ['저거', '설거지', '어디', '저거'],
#   ['개새', '사면', '다매', '시바'],
#   ['세력', '장난질', '오', '장이', '의미'],
#   [],
#   ['코인', '세력', '여자', '하나', '벚꽃', '구경'],
#   ['폴카', '폭주'],
#   ['필독', '강추'],
#   ['멸망', '수우', '개추'],
#   ['폴카'],
#   ['쿼크', '전가'],
#   ['폴카'],
#   ['전설'],
#   ['발련', '좆같', '코인'],
#   ['폴카', '인지'],
#   ['내일', '노가다'],
#   ['물타기', '생각', '미터', '얼기'],
#   ['계단식', '하락', '장이', '시작', '지금', '매수', '적기'],
#   ['사람',
#    '입장',
#    '친절',
#    '매물',
#    '하락',
#    '변동',
#    '초단',
#    '타로',
#    '어도',
#    '수익',
#    '지금',
#    '코인',
#    '가운데',
#    '최고'],
#   ['오늘', '난이도', '어렵'],
#   [],
#   ['오늘',
#    '쿼크',
#    '체인',
#    '때문',
#    '이상',
#    '이유',
#    '세력',
#    '요즘',
#    '이상',
#    '무지',
#    '매수',
#    '기다리',
#    '개씹',
#    '세력',
#    '개미'],
#   ['폴카', '산단', '매수'],
#   ['차이'],
#   ['욕심쟁이', '개추'],
#   ['어제', '쿼크', '사라'],
#   ['느그', '가족', '사셈'],
#   ['재조명'],
#   ['까', '오전', '복구', '불안'],
#   ['아크', '인대'],
#   ['발표', '영향', '머리', '아프', '하루', '종일', '코인'],
#   ['폴카', '점마', '어디'],
#   ['오늘', '무지', '준비'],
#   ['좆같', '희망', '회로', '모니터', '버리', '개추'],
#   ['오늘', '쿼크', '체인', '새기', '특징', '이거', '지금'],
#   ['발표', '영상', '하나'],
#   ['폭', '코인', '시빅', '지금', '고래', '매수'],
#   ['어제', '엽전', '장이', '그리우'],
#   ['안심', '사도', '호가'],
#   ['오늘', '개추', '비추'],
#   ['오늘', '쿼크', '체인', '새끼', '트럭'],
#   ['상승', '후회', '개추'],
#   ['발표', '요란'],
#   ['설마', '쿼크', '어제', '아서', '손절'],
#   ['려고',
#    '모으',
#    '고수',
#    '일봉',
#    '거래량',
#    '전고',
#    '거래량',
#    '매도',
#    '물량',
#    '분봉',
#    '매집',
#    '다수',
#    '발견',
#    '시간',
#    '저점',
#    '거래',
#    '대금',
#    '상위',
#    '유지',
#    '비트',
#    '상태',
#    '양호'],
#   ['그래픽', '메타', '버스'],
#   ['원위', '오늘', '발표', '기다리', '오열', '손절'],
#   ['메타', '버스', '혁신'],
#   ['때문', '개추', '대문'],
#   ['오미', '세', '매수', '매도'],
#   ['불나방', '오'],
#   ['횡보'],
#   ['천기누설', '대광', '유의'],
#   ['꼬라지', '내일', '시작', '관망'],
#   ['애초', '상장'],
#   ['호재', '지금'],
#   ['차트', '느', '안구', '손실', '새끼', '개추'],
#   ['불장', '반납', '개추'],
#   ['쿼크', '설겆이'],
#   ['코스모스', '이상', '추세', '전환', '저점', '다지기', '확인'],
#   ['손절', '부니', '가태'],
#   ['어제', '설거지', '려고', '세력', '노리', '역시', '악랄', '새끼'],
#   ['시체', '코인', '시체', '코인', '왜사'],
#   ['주말'],
#   ['손절', '복수'],
#   ['하나', '메타', '클럽'],
#   ['새끼', '손'],
#   ['오늘'],
#   ['사람', '대신'],
#   ['시아', '코인', '발련'],
#   ['클럽', '소리'],
#   ['쿼크', '체인', '호재', '걱정', '좌절', '금지', '정신', '시장'],
#   ['재산', '오늘', '졸업'],
#   ['발표', '지금', '가망', '이나'],
#   ['근데', '종목', '구조대'],
#   ['필독', '개월', '개월', '탈출', '터치', '개꿀'],
#   ['냉정', '차트', '저항', '지성', '기회비용', '니어', '비리', '천만', '반절', '비리'],
#   ['오늘', '설거지'],
#   ['인생', '배롱', '전고'],
#   ['오늘', '어렵', '개추'],
#   ['코인'],
#   ['선동', '당', '클럽'],
#   ['서첨', '코인'],
#   ['제로', '엑스', '장난질', '코인', '자체'],
#   ['오늘', '개추'],
#   ['오늘', '설거지'],
#   ['시드', '셀로', '기사', '고아'],
#   [],
#   ['어제', '자랑', '스럽', '평단', '여기', '예정'],
#   ['폭탄'],
#   ['비트', '어제', '일봉', '매매', '꼬리', '하락'],
#   ['오늘', '설거지', '개추'],
#   ['수익', '실현', '투리', '관망'],
#   ['장난질'],
#   ['시간', '느'],
#   ['설거지', '오픈'],
#   ['오늘', '코인', '코인', '거지', '장난질'],
#   ['바이', '이거', '오랜만', '시작', '영어', '울렁증', '그리고', '메타', '마스크', '개인', '지갑', '바이'],
#   ['오늘', '설거지', '패배', '개추', '오늘', '대단'],
#   ['대호황', '금관', '망충', '피눈물'],
#   ['준비', '짜리'],
#   ['오늘', '개추'],
#   ['발아'],
#   ['주말'],
#   ['시발', '불장', '무렵', '제일', '하루', '시드', '스트레스', '시드', '비율', '초단', '변동', '맛있'],
#   ['손절', '호재', '끝'],
#   ['언제', '오'],
#   ['엑스', '분봉', '살벌'],
#   ['모스',
#    '코인',
#    '올해',
#    '부동산',
#    '관련',
#    '메타',
#    '버스',
#    '코인',
#    '모스',
#    '코인',
#    '메타',
#    '버스',
#    '세계',
#    '지구'],
#   [],
#   ['포티'],
#   ['떨', '건가', '치', '토막'],
#   ['기후', '토큰', '어제', '오늘'],
#   ['코인', '마인드', '정신', '병원', '시드', '불리', '다음', '마냥', '기분', '좆같'],
#   ['시청',
#    '최근',
#    '손절',
#    '경험',
#    '타임',
#    '등등',
#    '백억',
#    '자산가',
#    '고수',
#    '아무',
#    '태우',
#    '개미',
#    '새끼',
#    '보유'],
#   [],
#   ['불장', '인과', '반인'],
#   ['대박', '원회', '귀하'],
#   ['무섭', '조정', '조금', '무섭', '저번'],
#   ['코인', '이랑', '개추'],
#   ['폭락', '분전'],
#   ['작년', '쿼크'],
#   ['성형', '수술비', '려고', '남음'],
#   ['발아', '개병', '거래소', '설거지', '새끼', '아서'],
#   ['이거', '차트', '혼자', '쳐먹', '연속', '양봉'],
#   ['어제', '쿼크', '매일', '쓰레기', '세력', '올리', '쿼크', '차례', '아서', '만', '늦잠'],
#   ['처박', '어제', '세력', '최대치', '여유', '부리'],
#   ['오늘', '설거지'],
#   ['위기'],
#   ['코인', '주제', '입금', '개추'],
#   ['인생'],
#   [],
#   ['어설프', '우왕좌왕', '사라', '어도', '오후', '출발', '예열', '모드', '저점'],
#   ['만큼', '보'],
#   ['오늘'],
#   ['저점', '개미', '털기'],
#   ['영상', '판단', '아서'],
#   ['발표'],
#   ['보'],
#   ['오늘', '비체', '느낌'],
#   ['보유', '종목', '빨간색', '하나'],
#   ['손절'],
#   ['최소', '프로', '쳐먹'],
#   ['셀로판지', '바뀌', '세끼', '개추'],
#   ['기사', '지금', '장난질', '웃기'],
#   ['양전하'],
#   ['물리', '장기', '이상', '탈출', '고도', '그때', '탈출'],
#   ['오늘', '종장', '패스', '세력', '물타기', '밖', '세력', '구조'],
#   ['발표', '시발'],
#   ['프로', '보', '사람'],
#   ['죽', '저번', '원이', '언제', '서원', '추세'],
#   ['오늘', '누구', '하나', '걸리', '심정', '새끼', '개추'],
#   ['설거지'],
#   [],
#   ['방구', '발표', '기다리'],
#   [],
#   ['시발', '주식'],
#   ['개창', '새기'],
#   ['새끼', '개추', '발련'],
#   ['오픈'],
#   ['아무것', '발표', '오늘', '하루', '종일'],
#   ['오늘', '개시', '설거지', '오', '시즌', '종료', '세력', '눈치', '수익', '실현', '느낌'],
#   ['시장', '매수', '매도', '떨', '외상', '스트레스', '장난', '기쁨', '잠시'],
#   [],
#   ['오늘', '대장', '코인', '시드', '사람'],
#   ['아크', '저점', '긴말'],
#   ['사람'],
#   ['세력'],
#   ['언제', '언제'],
#   ['원위', '사람', '어떻', '평생', '평단'],
#   ['누구', '대체', '코인', '하나', '장난', '새기', '누구'],
#   ['코인', '사람', '언급', '코인'],
#   ['장주', '어처', '코인', '신아', '하락', '장주'],
#   ['어도', '개추'],
#   ['조왕'],
#   ['오늘', '걸리', '새끼', '죽', '개추', '개시', '동안', '오늘', '분만', '허망', '개시'],
#   ['방금', '매수', '사람', '전체', '원래'],
#   ['비트', '킬로미터', '가노', '경이롭', '차트', '무지', '성매매', '자무', '지성'],
#   [],
#   ['배면', '오늘', '얼마', '졸업', '가능'],
#   ['오늘', '꼬라지', '퍼센트', '방법', '하나', '현재', '대비'],
#   ['오늘', '심상', '치가', '김치', '오늘', '설거지', '하락', '시작', '냄새'],
#   ['발표', '어디'],
#   [],
#   ['양전', '파란불', '개추'],
#   ['발표', '나락', '이여', '모르'],
#   ['복사기', '벌기', '세상', '제일', '방법', '전하'],
#   ['쿼크'],
#   ['말대', '양봉'],
#   ['개악', '설거지', '소리', '다야'],
#   [],
#   ['강간'],
#   ['킬로미터', '킬로미터', '홀더', '천국', '계단', '차트', '탑승', '완료', '어제', '차트', '보너스'],
#   [],
#   [],
#   [],
#   [],
#   ['세력', '차례', '대로'],
#   [],
#   [],
#   ['종목', '설거지', '려고', '역겹', '이렇', '나노'],
#   ['영상', '폭포수', '흐르'],
#   ['진자', '오늘', '설거지', '당하', '시발'],
#   ['설거지', '좆같'],
#   ['차트', '웃음', '새끼', '그렇'],
#   ['오늘', '역대', '설거지'],
#   ['시간', '개추'],
#   ['시발', '오늘', '설거지'],
#   ['어이', '털리'],
#   ['방구', '지금', '상태', '호재', '소멸', '사라', '지금', '정신', '나간', '호구'],
#   ['흑두루미'],
#   ['시발', '탑승', '데이트', '만약', '떨', '주일'],
#   ['떨어지'],
#   [],
#   ['오늘', '설거지', '웃기', '시간', '동안', '시드', '오'],
#   ['다음', '설거지'],
#   [],
#   ['설거지', '예상', '뻔하', '비트'],
#   ['질서', '퇴장', '그리고', '시드', '퇴장'],
#   ['장주'],
#   ['오늘', '설거지'],
#   ['고꾸라지'],
#   ['다음', '상승', '코인', '시빅', '세요'],
#   ['다음', '주주', '불기둥', '그리고', '계약', '흑우'],
#   ['코인', '시작', '분초', '순간', '극한', '고통', '새끼', '개추'],
#   ['다음', '설거지', '타자', '시빅'],
#   ['미안'],
#   ['시빅', '설거지', '가지'],
#   ['오늘', '설거지', '데이'],
#   ['매집', '세력', '당황', '차트', '파괴'],
#   ['장군'],
#   ['교대', '설거지', '세력', '새끼'],
#   ['사람', '개추'],
#   ['방구', '발표', '이렇', '오름폭', '오전', '오히려'],
#   ['매도', '어두', '려고', '매도', '시장', '아오'],
#   ['세상', '전한', '투자'],
#   ['그저께', '하락', '예감', '오늘', '설거지', '다행', '매수'],
#   ['손절', '흑우'],
#   ['방송', '한마디', '양봉', '광기', '무섭'],
#   ['시빅', '설거지', '모드'],
#   ['시빅', '분만'],
#   ['장군'],
#   ['현실', '구현'],
#   ['썸씽', '추세'],
#   ['지금', '코인', '상황', '두더지'],
#   ['시빅', '당하', '병신', '드랑'],
#   ['아크', '다음'],
#   ['시빅', '설거지', '종료'],
#   ['개씹'],
#   ['이거', '보', '매수'],
#   ['석우', '개호', '엔진', '언제', '토막'],
#   ['근데', '가치', '코인'],
#   ['방구', '이상', '평생', '개추'],
#   ['개시', '좆같', '설거지', '좆같', '시발'],
#   ['이거', '이거', '보너스', '빠', '마지막', '매수', '찬스', '지금', '흡수', '중임', '저세상', '차트'],
#   ['개새끼', '설거지'],
#   ['아크', '종료'],
#   ['오늘', '코인', '세력', '발련', '때문', '시드'],
#   ['다음', '아크', '설거지'],
#   ['이거'],
#   ['오늘', '경주마', '페이크', '쿼크', '세력', '차트', '병신'],
#   [],
#   ['제로', '엑스'],
#   ['이것', '시간', '백만언', '설겆이'],
#   ['설겆이', '당하', '개추'],
#   ['오늘', '각오'],
#   ['역겹'],
#   [],
#   ['블록',
#    '호재',
#    '마지막',
#    '물량',
#    '정리',
#    '거기',
#    '물리',
#    '개미',
#    '기도',
#    '이번',
#    '상장',
#    '폐지',
#    '수렴',
#    '얼른',
#    '물량',
#    '정리',
#    '추천'],
#   ['하나', '메탈'],
#   ['대장', '출발'],
#   ['시빅'],
#   ['호재', '나발', '소용없', '세력'],
#   ['기사', '식사', '하', '오심'],
#   ['발표', '그래픽'],
#   ['오늘', '장군', '조정'],
#   ['야바위', '코인', '보', '이것저것', '날림'],
#   [],
#   ['수면', '매매', '흑우', '그렇'],
#   ['매집'],
#   ['방구', '새기', '척하', '역겨우', '축배'],
#   [],
#   ['계속'],
#   ['제발'],
#   ['오늘', '설거지', '데이', '나락', '장초', '프로', '승리자', '쇠리'],
#   ['속보', '출발'],
#   ['이번'],
#   ['바닥',
#    '바닥',
#    '차트',
#    '무지',
#    '지금',
#    '아서',
#    '이거',
#    '기다리',
#    '번장',
#    '저번',
#    '경험',
#    '추세',
#    '킬로미터',
#    '진화'],
#   ['비트', '지금', '돌파'],
#   ['나락'],
#   ['다음', '타자'],
#   [],
#   ['스택', '방금', '사람'],
#   ['무빙', '하나', '좆같', '전부', '꼬리', '만드'],
#   [],
#   ['방금', '아크', '사람', '소감'],
#   ['설거지', '설마'],
#   ['코인', '인생'],
#   ['메타', '버스', '고글', '한데'],
#   ['설거지'],
#   ['택스', '파멸', '운지'],
#   ['경주마', '새끼', '시간', '더럽'],
#   ['발련'],
#   ['아침', '물리', '형편없', '게이'],
#   ['방금', '시빅', '사람', '이거'],
#   ['병신', '비트'],
#   ['개미', '설거지', '경고', '사이언스'],
#   ['현재', '세력', '개추'],
#   [],
#   ['폴카', '신련', '새끼', '정체'],
#   ['순환'],
#   ['이번', '승장', '개월', '탈출', '며칠', '하락', '그때', '그때'],
#   ['짜리', '설가', '개추'],
#   ['오늘',
#    '경우',
#    '나',
#    '예전',
#    '친구',
#    '소설',
#    '생각',
#    '지금',
#    '상황',
#    '이야기',
#    '설거지',
#    '잔반',
#    '식중독',
#    '걸리'],
#   ['바늘', '지금', '가두리'],
#   ['이번', '대장'],
#   ['해외'],
#   ['지치'],
#   ['설거지', '겁먹', '올리'],
#   ['택스', '분만', '병신', '코인'],
#   ['성하'],
#   ['중순', '월말', '그정', '중순', '란', '보', '빠르', '인생', '역전', '호재'],
#   ['아크', '병신'],
#   ['근일', '대표', '세력', '닦이', '절대', '계속', '무한', '반복'],
#   ['원래', '상태'],
#   ['비트', '경고', '설거지', '인지', '인지', '구분', '가능'],
#   [],
#   ['언제', '장대', '언제', '장대', '언제'],
#   ['오늘', '성공', '프로', '이내', '라면', '성공', '오늘', '코인'],
#   ['개월', '선배'],
#   ['설거지', '사람', '개추'],
#   ['저거'],
#   ['버리'],
#   ['이름', '얼굴', '모르', '새끼', '개추'],
#   [],
#   ['보통', '친남매', '스킨', '어디', '키스'],
#   ['대장'],
#   ['천하제일', '설거지', '대회'],
#   [],
#   ['고점', '개월', '탈출'],
#   ['장난질', '능지', '수준', '그럼', '코인', '관두', '병신'],
#   ['오늘', '세력', '작정', '이유', '이렇', '대형', '세력', '압박', '물량', '챙기', '서임'],
#   ['새끼', '이유'],
#   ['메타', '버스', '영상', '대박'],
#   ['쓰레기', '홀드'],
#   ['웃기'],
#   [],
#   ['작전', '무섭'],
#   ['우울', '시발', '니어', '줄때'],
#   ['아크', '최고점', '질문', '새기'],
#   ['시간', '정보'],
#   ['분만'],
#   ['오늘', '급등', '시드', '코인', '추천'],
#   ['꼬라박'],
#   ['메타'],
#   ['불장', '반납', '개추'],
#   ['쿼크', '체인', '시작'],
#   ['피뢰침', '내', '지랄'],
#   ['오늘'],
#   ['새끼', '눈치', '보네'],
#   ['개추'],
#   ['오늘', '드림', '횡보', '이내', '기다리', '이내', '추천'],
#   ['설거지', '모르', '개추'],
#   ['쿼크', '기사', '부족', '설거지', '시작'],
#   ['오늘', '관망', '신임'],
#   ['오늘', '아무것', '관찰', '기분'],
#   ['순환', '피뢰침', '웃기'],
#   ['엽전', '메타', '동전', '메타'],
#   ['시드', '좆같', '아서', '개추'],
#   ['병신', '손절', '치', '현금'],
#   ['디비전', '원래', '짜리', '저점'],
#   ['설거지', '개추'],
#   ['파워', '버리'],
#   ['통합'],
#   ['이거', '석우', '방어', '려고', '총알', '확보', '전쟁', '시작'],
#   ['좆같'],
#   ['근데', '어매', '며칠', '조정', '개시', '파란색', '고아'],
#   ['어지럽', '손익', '토막'],
#   ['물리',
#    '개월',
#    '경험담',
#    '고점',
#    '최초',
#    '진입',
#    '그리고',
#    '그때',
#    '이후',
#    '개월',
#    '계속',
#    '꼬라박',
#    '물타기',
#    '평단',
#    '어제',
#    '탈출',
#    '분할',
#    '매도',
#    '오늘',
#    '꼬라박',
#    '보이',
#    '기사',
#    '짓거리',
#    '그리고',
#    '새끼',
#    '조심',
#    '어설프'],
#   ['오늘',
#    '저쩌',
#    '미안',
#    '한데',
#    '지금',
#    '최적화',
#    '현실',
#    '그동안',
#    '세력',
#    '잠시',
#    '세력',
#    '기간',
#    '동안',
#    '물량',
#    '매집',
#    '내일',
#    '시작',
#    '오늘',
#    '파리',
#    '날리',
#    '시작'],
#   ['평단'],
#   ['순환', '순환', '설거지', '시발', '최근', '시드', '오늘', '어도', '소소', '오늘', '시드', '순식간'],
#   ['아크', '내열', '순간'],
#   ['해장', '려고', '짬뽕', '이나', '오늘', '짬뽕', '그릇'],
#   ['웃음기', '사리', '지면', '개추'],
#   ['병신'],
#   ['제로', '엑스'],
#   ['새끼'],
#   ['지금', '때문', '빠', '좆같'],
#   ['이상', '오늘'],
#   ['호구', '새끼', '어떻', '손절', '역사'],
#   ['세력',
#    '오늘',
#    '파뢰',
#    '이유',
#    '세력',
#    '개미',
#    '주일',
#    '기간',
#    '동안',
#    '나락',
#    '인지',
#    '개미',
#    '시',
#    '지금',
#    '현물',
#    '호재',
#    '개미',
#    '모이',
#    '세력',
#    '코인',
#    '이란'],
#   ['경주마', '시드', '세력', '불장', '개미', '털기', '당하'],
#   ['앵커', '병신', '병신', '병신'],
#   ['시체', '아서', '가지'],
#   ['썸씽', '세력'],
#   ['병신'],
#   ['속보', '발표'],
#   ['수고', '최소', '개월'],
#   ['오늘', '급등', '시드', '이상', '추천', '인원', '체크', '댓글'],
#   ['아침', '손절', '한수', '새끼', '저기', '바닥'],
#   ['기상', '좆같'],
#   ['시발', '떨', '개시', '시발'],
#   ['분위기', '개추'],
#   ['정답',
#    '이해',
#    '지금',
#    '불장',
#    '아무',
#    '매수',
#    '절가',
#    '매도',
#    '절대',
#    '건드리',
#    '손절',
#    '손절',
#    '기도'],
#   ['경주마', '주일', '동안', '설거지', '당하', '원숭이', '두목'],
#   ['그래프', '폭', '그래프'],
#   ['코인'],
#   ['악재', '지금', '이유', '포지션', '종료', '관망', '왜냐하면', '세력', '의논', '휴가', '시즌'],
#   ['자기', '불안', '매도', '칭찬', '자신'],
#   ['오늘', '내일', '비트', '아서'],
#   [],
#   ['영상', '개구리', '손절', '우리'],
#   ['현금', '비트', '떨어지'],
#   ['설거지', '장이', '코인', '지사기', '어의'],
#   ['저거', '상승', '시작', '청산'],
#   ['시발', '안심'],
#   ['코인'],
#   ['비트', '마이너스', '세력', '설거지', '타임'],
#   ['비트', '파란불', '눈치', '챙기', '오늘'],
#   ['세력', '고맙', '생각', '수익'],
#   ['발표', '기다리', '등신', '오늘', '어제', '공지', '발표', '영상', '기다리'],
#   ['설거지', '생각', '개추'],
#   [],
#   ['지금',
#    '빠',
#    '분위기',
#    '코인',
#    '유저',
#    '패턴',
#    '순서',
#    '다음',
#    '대장',
#    '순환',
#    '개추',
#    '눈치',
#    '대충'],
#   ['오늘', '경마', '설거지', '무빙', '다음', '전이'],
#   ['조까', '주일', '번거', '순삭'],
#   ['메타', '버스'],
#   ['방구석',
#    '코인',
#    '지겹',
#    '지겨우',
#    '소리',
#    '지월',
#    '포티',
#    '상장',
#    '올해',
#    '려고',
#    '코인',
#    '불장',
#    '모니터',
#    '배달',
#    '이나'],
#   ['지금', '와중', '코인', '개떡', '상각'],
#   ['스케일', '다르', '불곰'],
#   ['하이', '병신', '코인', '대박', '코인', '세력', '개미', '보', '세력', '병신', '대가리', '새기'],
#   ['이나'],
#   ['오늘', '설거지', '개추'],
#   ['진데', '시발', '순간', '기쁘', '양심', '새끼', '불장'],
#   ['이', '우리', '전환', '세기', '계속', '지랄'],
#   ['지정', '매도', '매도', '예약', '오류', '코인', '시장', '가로'],
#   ['도박', '도박', '짓거리', '날리', '인생', '아깝'],
#   ['가', '비트', '도미', '이번'],
#   ['엽전'],
#   ['오늘',
#    '내일',
#    '비트',
#    '빠',
#    '이유',
#    '채굴',
#    '물량',
#    '중임',
#    '올해',
#    '상승',
#    '얘기',
#    '채굴',
#    '고점',
#    '판단',
#    '중임',
#    '출금',
#    '일상',
#    '복귀'],
#   ['치킨', '개추'],
#   ['공포'],
#   ['시바', '어제', '이유'],
#   ['어제', '고점', '흑우'],
#   ['대호황', '금관', '망충', '피눈물'],
#   ['질퀴',
#    '벌레',
#    '바뀌',
#    '웃기',
#    '아침',
#    '폭락',
#    '사실',
#    '폭락',
#    '사실',
#    '폭락',
#    '사실',
#    '폭락',
#    '행사'],
#   ['내일', '직장', '이나', '현물', '시작'],
#   ['운지', '시작', '병신'],
#   ['벽력', '일섬', '재미없', '개추', '보람'],
#   ['차트'],
#   [],
#   ['방구', '때문'],
#   ['방법'],
#   ['시간'],
#   ['설거지', '시작'],
#   ['짜증', '손절', '폭락', '멈추'],
#   ['오늘', '시발', '맛있', '아침', '급등', '시드', '빨아먹', '시드', '천만', '하락', '섹스'],
#   [],
#   ['쿼크', '올리', '탈출', '본전', '탈출', '욕심', '부리'],
#   ['시드',
#    '동안',
#    '손절',
#    '니어',
#    '어제',
#    '니어',
#    '천만',
#    '이상',
#    '시발',
#    '어제',
#    '꼬라박',
#    '아서',
#    '결국'],
#   ['시작', '수세미', '방금', '준비'],
#   ['인생',
#    '이유',
#    '성공',
#    '모두',
#    '질투',
#    '하나',
#    '때문',
#    '필요',
#    '하나',
#    '망가',
#    '이해',
#    '코인',
#    '왕자'],
#   ['사람'],
#   ['오늘', '시드', '변화'],
#   [],
#   ['느낌', '현금', '개추'],
#   ['동안', '현실', '부정', '깨'],
#   ['폴카', '구조', '어디'],
#   [],
#   ['제트',
#    '기능',
#    '기능',
#    '기사',
#    '뿌림',
#    '조까',
#    '사람',
#    '다운',
#    '다운',
#    '메타',
#    '버스',
#    '쓰레기',
#    '타운',
#    '짝퉁',
#    '메타',
#    '버스',
#    '메타',
#    '버스',
#    '연동',
#    '이거',
#    '방송',
#    '베타',
#    '영상',
#    '이거',
#    '타운',
#    '짝퉁',
#    '실제',
#    '모습',
#    '이거',
#    '실제',
#    '작동',
#    '모습',
#    '홍보',
#    '미팅',
#    '제이',
#    '당황',
#    '코스닥',
#    '상장',
#    '달라붙',
#    '근무',
#    '직원',
#    '유령',
#    '법인',
#    '도토리',
#    '방송',
#    '희대',
#    '사기',
#    '현재',
#    '진행',
#    '사건',
#    '알아보',
#    '코스닥',
#    '장사',
#    '사기',
#    '기사',
#    '띄우',
#    '이거',
#    '하나',
#    '수년',
#    '동안',
#    '계속'],
#   ['시드', '늘리', '시드', '고대', '물림'],
#   ['오늘', '설거지', '개운', '망충', '개추'],
#   ['쓰레',
#    '누사',
#    '사라',
#    '누사',
#    '쓰레',
#    '변경',
#    '대로',
#    '코인',
#    '개미',
#    '생각',
#    '누사',
#    '세력',
#    '홀더',
#    '아프',
#    '밖',
#    '대로',
#    '누사',
#    '변환',
#    '쓰레',
#    '보안',
#    '대장',
#    '코인',
#    '합병',
#    '슈팅',
#    '보단',
#    '우상',
#    '향일',
#    '확률',
#    '아서',
#    '변환',
#    '사이',
#    '걱정',
#    '보단',
#    '누사',
#    '장난질',
#    '기다리',
#    '확률',
#    '게임'],
#   ['클럽', '대상', '천기누설'],
#   [],
#   ['오늘', '아침'],
#   ['교육', '불나', '방충', '고점', '조리', '시세', '충전부', '뇌수', '흐름'],
#   ['쓰레'],
#   ['믿음', '대부분', '도박', '넘'],
#   ['가치', '흐르', '어제'],
#   ['시발'],
#   ['나라'],
#   ['언제'],
#   ['내', '어제', '원일'],
#   ['호재', '발표', '폭락', '대박'],
#   ['비트',
#    '일봉',
#    '오늘',
#    '비트',
#    '보이',
#    '문제',
#    '저항',
#    '채굴',
#    '물량',
#    '거래량',
#    '상승',
#    '가능',
#    '보이',
#    '중요',
#    '이거',
#    '지금',
#    '하락',
#    '건강',
#    '조정',
#    '하락',
#    '현금화',
#    '여기',
#    '물리',
#    '정신',
#    '일상',
#    '복귀'],
#   ['쓰레', '점마', '꼴', '설거지'],
#   ['끝', '비골', '체인', '링크', '사고', '삭제'],
#   ['운지', '운지'],
#   ['설거지', '비트', '허매', '세력', '설거지', '작업', '멸치', '대가리', '새끼'],
#   ['코인',
#    '년차',
#    '오늘',
#    '패턴',
#    '지금',
#    '코인',
#    '설거지',
#    '프로',
#    '올리',
#    '설거지',
#    '보이',
#    '지금',
#    '코인',
#    '아도',
#    '프로',
#    '근데',
#    '코인',
#    '결국',
#    '떨어지',
#    '근데',
#    '오늘',
#    '비트',
#    '개미',
#    '물량',
#    '오',
#    '털어먹',
#    '얘기',
#    '코인',
#    '지금',
#    '프로',
#    '프로',
#    '며칠',
#    '프로',
#    '상승',
#    '탈출',
#    '자산',
#    '묶',
#    '절대',
#    '오늘'],
#   ['타'],
#   ['각수렴', '급등', '준비'],
#   ['불장', '개추'],
#   ['요즘', '여자', '인생', '매매혼', '승혼', '노리', '여자', '명중', '명인', '시대', '거래', '시대'],
#   ['쇼트', '언제'],
#   ['단기간', '김치', '코인', '김치', '코인'],
#   ['제로', '엑스', '발련', '개시', '발련'],
#   [],
#   ['스릴', '오늘'],
#   ['시각', '사람', '코인'],
#   ['시발', '호로', '섹스', '현물', '마지막', '기회'],
#   ...],
#  [['박타', '마다'],
#   ['출발'],
#   ['알파', '쿼크'],
#   ['경주마', '시발'],
#   [],
#   [],
#   [],
#   ['자도'],
#   [],
#   ['오늘'],
#   ['도지'],
#   ['오늘', '알파', '쿼크', '왁스', '언제', '끝', '대체'],
#   ['루프', '방심', '프로', '욕망', '대형', '호재', '나중', '후회', '머리', '대형', '호재', '기다리'],
#   ['경주마', '설거지', '장임', '경주마', '제자리'],
#   ['전원', '구출', '완료'],
#   ['괜찮'],
#   ['엔진', '코인'],
#   ['마지막',
#    '복지',
#    '까보',
#    '소임',
#    '이름',
#    '복지',
#    '실제',
#    '사원',
#    '혜택',
#    '대부분',
#    '워라',
#    '무엇',
#    '보',
#    '전부',
#    '만족',
#    '직장',
#    '가족',
#    '친구',
#    '지인',
#    '본인',
#    '직장',
#    '직장',
#    '기업',
#    '모르',
#    '때문',
#    '나중',
#    '예능',
#    '마냥',
#    '직장',
#    '맞추',
#    '게임'],
#   ['오늘', '얼른'],
#   ['오늘', '목표', '이', '게즈'],
#   ['오늘', '칠장', '군가'],
#   ['택스', '오늘', '느낌', '지금', '빠'],
#   ['프로', '경주마', '불장'],
#   ['알파', '쿼크', '어디'],
#   ['거기'],
#   ['도지', '자리'],
#   ['오늘', '떨어지', '이유'],
#   ['아티스트'],
#   ['세요'],
#   ['시작'],
#   ['부처', '다면', '오늘'],
#   ['플레이', '웅지'],
#   ['장군'],
#   ['지금', '비트', '상승', '멈추', '횡보', '조정장', '불장', '타령', '지금', '불장'],
#   ['순간', '잔고', '등주'],
#   ['언제', '입대'],
#   ['시장', '나'],
#   ['오늘'],
#   ['이면',
#    '인생',
#    '그렇',
#    '일생',
#    '지계',
#    '어유',
#    '일년지계',
#    '지계',
#    '어인',
#    '일생',
#    '계획',
#    '계획',
#    '하루',
#    '계획',
#    '새벽',
#    '깨달음',
#    '일생',
#    '나이',
#    '깨',
#    '내년',
#    '학습',
#    '지금',
#    '수학',
#    '영어',
#    '공부',
#    '점심',
#    '저녁',
#    '집중',
#    '집중',
#    '게임',
#    '이나',
#    '시간',
#    '새벽',
#    '공부',
#    '시간',
#    '하루',
#    '시간',
#    '공부',
#    '오늘',
#    '실패',
#    '포기',
#    '공부',
#    '지속',
#    '새벽',
#    '공부',
#    '허허',
#    '내일',
#    '장사',
#    '천만',
#    '번',
#    '생업',
#    '도박',
#    '중독자',
#    '잔고',
#    '정보',
#    '통신',
#    '공학',
#    '예비',
#    '인생',
#    '하루',
#    '평균',
#    '공부',
#    '시간',
#    '시간',
#    '수학',
#    '영어',
#    '공부'],
#   ['알파', '쿼크'],
#   [],
#   ['하', '야지', '천국', '아도', '본전', '매도'],
#   [],
#   ['스팀', '달러'],
#   ['매수', '고고'],
#   ['중소기업', '취직', '어디', '주변', '사람', '만약', '다면', '설명', '중소기업', '설명'],
#   ['알파', '쿼크', '얼마', '탈출', '어도'],
#   ['대장', '새끼', '특징'],
#   ['센박'],
#   ['닥'],
#   ['박인', '건가', '박인', '건가'],
#   ['절반', '매도', '절반', '매도'],
#   ['오늘'],
#   ['하루하루', '저점'],
#   ['호재', '설겆이'],
#   ['경주마'],
#   [],
#   ['리니어'],
#   ['에스'],
#   [],
#   [],
#   ['오늘', '박이'],
#   ['아르고', '동의'],
#   ['멸망'],
#   [],
#   ['어디', '가노'],
#   ['매수'],
#   ['한데', '오늘', '구나'],
#   ['내년', '세계', '최초', '원격', '의료', '플랫', '출시'],
#   ['신'],
#   ['좆같', '가요'],
#   ['주목', '움직이'],
#   ['엔진', '시발'],
#   ['알파', '쿼크', '유일', '오랜만'],
#   ['매도'],
#   ['오미', '세', '마지막', '불꽃', '며칠'],
#   ['엔진'],
#   [],
#   ['교대', '본인', '이유', '군필'],
#   ['진입', '마지막', '불꽃'],
#   ['진정', '친구', '이유'],
#   ['매수'],
#   ['교대', '본인', '이유', '군필'],
#   ['어제', '오늘', '엔진', '탈출', '개꿀'],
#   ['마스크'],
#   ['주말'],
#   ['오늘', '치킨'],
#   [],
#   ['오늘', '근고', '돌파'],
#   ['코인', '이나', '주식', '패닉', '오히려', '위기감', '묘하', '꼴리', '쾌감', '특별'],
#   ['결국', '짜리'],
#   ['아서', '판단', '탑승'],
#   ['우상', '향중', '슈팅'],
#   ['엔진', '조간'],
#   ['마스크', '구조'],
#   ['돈나무', '언니', '전부', '판매', '자산', '하락'],
#   ['양전'],
#   ['지금', '개미', '이거', '어디', '치솟'],
#   ['돈나', '무년', '돈나무'],
#   [],
#   ['파일', '코인'],
#   ['알파', '다음', '오토', '순환'],
#   ['개미', '올리', '덕분'],
#   ['오늘', '경주마', '박죽'],
#   [],
#   ['횡보', '최소', '언제', '사이', '용돈'],
#   ['경주마', '이리', '사료'],
#   ['박도'],
#   ['도망'],
#   [],
#   ['현실', '매수'],
#   ['점마', '어디', '가노'],
#   ['어제', '정리'],
#   ['박이'],
#   ['도망'],
#   ['운지'],
#   [],
#   ['코인', '망하', '보'],
#   ['언제'],
#   ['설거지'],
#   ['돈나무', '언니', '도지', '도지'],
#   ['부모',
#    '원인',
#    '차단',
#    '게임',
#    '부모',
#    '싫',
#    '그럼',
#    '컴퓨터',
#    '노트북',
#    '자체',
#    '버리',
#    '그리고',
#    '빠르',
#    '개월',
#    '느리',
#    '고물',
#    '종목',
#    '예전',
#    '아이',
#    '기간',
#    '먹통',
#    '게임',
#    '기도'],
#   ['박죽', '장기', '홀더', '정도'],
#   ['출발'],
#   ['토설', '대노'],
#   [],
#   ['상장', '때문', '지금', '저점'],
#   ['다음', '어디'],
#   ['방금', '흑두루미', '설겆이', '타임'],
#   ['매도'],
#   ['오늘', '오미', '무한', '어제', '오늘', '매집', '매크로', '무한'],
#   ['교대', '본인', '이유', '군필'],
#   ['지금'],
#   ['괜찮', '정도', '려고', '괜찮', '생각'],
#   ['기사', '타인', '시가', '매수', '대신', '그렇'],
#   [],
#   ['썸씽', '시발', '며칠'],
#   ['요즘', '메타', '호재', '민감', '종목', '다급', '등주', '연연', '찍어누르', '매수'],
#   ['면매', '개꿀'],
#   ['제발'],
#   ['미아', '심심', '저녁'],
#   ['양전하', '다행'],
#   ['양전'],
#   ['엔진', '기쁨', '음전'],
#   ['박아', '올리', '대결'],
#   [],
#   ['다음', '오미', '세'],
#   [],
#   ['양전', '오늘'],
#   ['근본', '무빙', '보이', '코인', '야지', '급등', '노리', '물리', '새끼'],
#   [],
#   ['생각', '사실', '냅', '삐'],
#   ['루프', '명품', '코인', '루프', '사라', '루프', '사토'],
#   ['양전'],
#   ['대황'],
#   ['이상', '문자', '답장'],
#   ['버프'],
#   ['신년'],
#   ['박죽'],
#   ['여기', '동질', '고아', '좆같', '새끼', '자식'],
#   ['코인', '광고', '순수', '행동'],
#   ['박아', '물량', '그거', '올리', '려고', '디시', '올리'],
#   ['일어', '왁스', '그거'],
#   ['오미', '새기'],
#   ['코인', '주식', '보'],
#   ['본인',
#    '고등학교',
#    '대학교',
#    '초등',
#    '학교',
#    '번호',
#    '세우',
#    '부모',
#    '게임',
#    '느',
#    '귀찮',
#    '아서',
#    '저녁',
#    '아침',
#    '그래서',
#    '점심',
#    '학교',
#    '급식',
#    '밖',
#    '지금',
#    '그때',
#    '매일',
#    '매일',
#    '고등학교',
#    '학년',
#    '성장',
#    '생각',
#    '대학',
#    '입학',
#    '자취',
#    '생각',
#    '모르',
#    '매일',
#    '매일',
#    '고기',
#    '계란',
#    '쳐먹',
#    '우유',
#    '하루',
#    '비타민',
#    '영양제',
#    '턱걸이',
#    '조짐',
#    '크기',
#    '시작',
#    '부족',
#    '행복',
#    '입대',
#    '훈련소',
#    '간식',
#    '자대',
#    '상병',
#    '지금',
#    '여기',
#    '정도',
#    '만족',
#    '유전',
#    '영양',
#    '중요',
#    '사실',
#    '깨',
#    '요즘',
#    '본인',
#    '성장기',
#    '라면',
#    '만약',
#    '자녀',
#    '다면',
#    '절대',
#    '굶',
#    '바람'],
#   ['하나'],
#   ['시발', '트론', '새끼', '언제'],
#   ['오늘', '경주마', '음전', '쉬려', '경주마', '아리', '거보', '양전', '귀환'],
#   ['지금', '사도', '나'],
#   ['매도', '떨어지', '혈압'],
#   ['근데', '엔진', '언급', '자체'],
#   ['모모', '채널', '정보', '제일', '빠르'],
#   ['버프'],
#   [],
#   ['어제'],
#   ['엔진', '이거', '탈출', '가능'],
#   ['협업', '구만'],
#   ['음전', '설레발'],
#   ['사지'],
#   ['선택', '오병'],
#   ['역사'],
#   ['바이'],
#   ['개새끼'],
#   [],
#   ['오늘', '불나방', '수익'],
#   ['내일', '개씹', '불장', '두루치기'],
#   ['거래', '대금'],
#   ['긴급', '마스크', '참고', '오늘', '자살'],
#   ['센박', '절대'],
#   ['미세', '이탈'],
#   ['오늘', '느낌', '친구'],
#   ['병신', '새끼'],
#   ['리플', '이랑', '비토'],
#   ['예술'],
#   ['폴카'],
#   ['상장',
#    '제일',
#    '병신',
#    '홀더',
#    '그날',
#    '시드',
#    '바이',
#    '전날',
#    '더럽',
#    '엄주',
#    '원래',
#    '고독',
#    '보통',
#    '언급'],
#   ['오늘', '하루'],
#   ['음전', '아오'],
#   ['어제', '새벽', '염병', '병신', '대가리', '수준'],
#   ['짱깨'],
#   ['아모', '코인', '상장', '오늘', '석우'],
#   ['오', '코인', '이것'],
#   ['왁스', '언제'],
#   ['오늘', '대장'],
#   ['여자', '팬티', '요즘', '시세', '얼마', '정도'],
#   ['이거', '일주일', '탈출', '가능'],
#   ['저점', '인증'],
#   ['호재', '코인', '이나', '코인'],
#   [],
#   ['엔진'],
#   ['대통령', '총리', '주석', '차이점'],
#   ['오미', '오늘', '인재', '오신'],
#   ['오미', '세력', '어제', '미안', '해요', '제발'],
#   ['색히'],
#   [],
#   ['엔진', '조금', '만큼', '내', '경우', '속아'],
#   ['박죽', '지금', '대가리', '수면', '이상'],
#   ['황부'],
#   ['코인', '생각', '벌기', '요즘'],
#   ['보소', '이거'],
#   ['보라', '카카오'],
#   ['설거지', '낚이', '지금', '도지'],
#   ['코인', '가치', '투자', '소리', '개소리', '개추', '도박'],
#   ['북벌', '시작'],
#   ['이유'],
#   ['항해', '시작'],
#   ['바이', '비트', '패드'],
#   ['매수', '고고'],
#   ['부탁', '생활비', '투자', '투자', '생각'],
#   ['오미', '세', '병신', '코인', '근데', '저거', '병신'],
#   ['어제', '매도', '손절', '고맙', '시발'],
#   ['급등', '언제', '모르'],
#   ['이브', '형제', '홀더', '만든'],
#   ['여자', '자지'],
#   ['동안', '오미', '매집', '세력', '가지', '어도'],
#   ['코인',
#    '세금',
#    '질문',
#    '원화',
#    '입금',
#    '비트',
#    '입금',
#    '다음',
#    '거래',
#    '시작',
#    '수익',
#    '기준',
#    '입금',
#    '시간',
#    '코인',
#    '원화',
#    '가격'],
#   ['주일', '새벽'],
#   ['파멸', '상승'],
#   ['어제', '근데', '시작', '밑바닥', '지지', '오후', '지금'],
#   ['허접', '사람', '알파', '반응', '오미', '외고'],
#   ['시각', '최고', '병신', '이나', '어미', '어미', '새끼'],
#   ['코인', '코인', '어디', '거래소'],
#   ['코인', '원탑'],
#   ['자기', '생태', '구축', '코인', '폴카', '코스모스'],
#   ['양전', '기모'],
#   ['음전'],
#   [],
#   ['오늘', '전고', '자기', '최저'],
#   [],
#   ['코인',
#    '도박',
#    '지사기',
#    '폭탄',
#    '호구',
#    '복사',
#    '가격',
#    '호구',
#    '복사',
#    '결국',
#    '복사',
#    '배팅',
#    '금액',
#    '만큼',
#    '주머니',
#    '가치',
#    '가치',
#    '폭탄',
#    '개미',
#    '낚이',
#    '아무',
#    '소용'],
#   ['시체', '꼬꾸라지'],
#   ['전고', '부대장', '대장', '신흥', '무섭'],
#   ['굴리', '굴리', '시발'],
#   ['코인', '이성', '그램', '모모', '채널'],
#   ['코인', '천만', '그거', '밖', '사람', '벌어지'],
#   ['미아', '호재'],
#   ['알파', '쿼크', '어제', '오늘', '다리'],
#   ['코인', '거래'],
#   ['비트', '할배', '슈팅'],
#   ['원래', '이렇', '영양제', '아야', '하나'],
#   ['발기'],
#   ['저거'],
#   ['킬러', '지롤', '소리', '개추'],
#   [],
#   ['풀발', '전고'],
#   ['시작', '피해'],
#   ['짱깨', '조심'],
#   ['살판'],
#   ['도착', '돌파'],
#   ['비트', '보소'],
#   [],
#   ['개조', '지노'],
#   ['경주마', '이리', '불장', '불장'],
#   ['성대'],
#   ['지금', '조정', '상승'],
#   ['이러', '내리꽂', '느낌', '심심', '지속', '하락', '사람', '무섭'],
#   ['비트', '대장', '조심'],
#   ['보유', '코인', '시드', '늘리'],
#   ['높이',
#    '병신',
#    '새끼',
#    '이랑',
#    '말싸움',
#    '설명',
#    '대가리',
#    '깨',
#    '마냥',
#    '병신',
#    '지껄이',
#    '그래서',
#    '깨',
#    '병신',
#    '대가리',
#    '지능',
#    '수준',
#    '따라오',
#    '고로',
#    '병신',
#    '말싸움',
#    '삭제'],
#   ['김치', '코인', '시작'],
#   [],
#   ['원래', '오미'],
#   ['도지', '누사'],
#   ['슈팅'],
#   ['성대', '무의미'],
#   ['오후', '전하', '오'],
#   [],
#   ['흑우', '차트', '모르', '전형', '지지대', '차트', '선택', '연말'],
#   ['미세', '만간'],
#   ['선물', '개꿀'],
#   ['버프', '안산', '흑우', '여기'],
#   ['오다'],
#   ['근데', '나락'],
#   ['속보', '폐공'],
#   ['시발', '별도', '생태', '구축', '건가', '성대'],
#   ['강세', '파일', '코인', '괜찮'],
#   ['생각', '물량', '정리', '보이'],
#   ['하루하루', '줄어드', '기쁘', '개추'],
#   ['폴라리스'],
#   ['소다', '인유', '며칠', '실수', '시장', '가로', '매도', '급락', '지금', '저점', '매수', '타이밍'],
#   ['오미', '오호'],
#   ['여기', '도지', '뒷다리', '보이'],
#   ['이거', '심상', '저점', '느낌'],
#   ['계륵'],
#   [],
#   ['미아'],
#   ['마음', '어도'],
#   ['오늘'],
#   ['큰일', '어디'],
#   ['비체'],
#   ['마스크', '장난', '참고', '오늘', '자살'],
#   ['세력', '새끼', '기어', '해외'],
#   ['소다',
#    '코인',
#    '매수',
#    '타이밍',
#    '바보',
#    '며칠',
#    '시장',
#    '가로',
#    '매도',
#    '급락',
#    '저점',
#    '사이',
#    '매수',
#    '타이밍',
#    '최소',
#    '기존',
#    '평단'],
#   ['흑인', '발기'],
#   ['소다', '개꿀', '유의', '무시', '폭주', '기관차', '지정'],
#   ['경주마', '창녀', '색기'],
#   [],
#   ['감안', '소리야'],
#   ['물리', '얘기', '멘탈'],
#   ['주식', '하위', '호환', '프로', '국장'],
#   ['어제', '청산', '오늘', '아침', '청산'],
#   [],
#   ['마스크', '오늘', '자살', '다리'],
#   ['개시', '시발'],
#   ['현물', '마진'],
#   [],
#   ['탱크'],
#   ['주식', '세금'],
#   ['마스크', '새끼', '필요', '사람', '지갑'],
#   ['바이', '비트'],
#   [],
#   ['김치', '불장', '모르', '단순', '보', '호재', '미래', '전망', '덩치', '메이'],
#   ['이면',
#    '인생',
#    '그렇',
#    '일생',
#    '지계',
#    '어유',
#    '일년지계',
#    '지계',
#    '어인',
#    '일생',
#    '계획',
#    '계획',
#    '하루',
#    '계획',
#    '새벽',
#    '일생',
#    '계획',
#    '나이',
#    '계획',
#    '나이',
#    '장사',
#    '천만',
#    '번',
#    '생업',
#    '도박',
#    '중독자',
#    '잔고',
#    '정보',
#    '통신',
#    '공학',
#    '예비',
#    '인생',
#    '하루',
#    '평균',
#    '공부',
#    '시간',
#    '시간',
#    '수학',
#    '영어',
#    '공부'],
#   ['이나', '모레', '도배', '버프', '지금'],
#   [],
#   ['고체', '포기', '출반'],
#   [],
#   ['미세'],
#   ['오미', '마지막', '인륜', '시간'],
#   ['현금', '관망', '느낌', '이상', '조정', '저점'],
#   ['마스크', '지갑', '댓글'],
#   ['어미', '놀', '지갑', '잠기'],
#   ['준비', '매도'],
#   ['에이다', '메이', '저장', '시작', '발기', '에이다'],
#   ['지금', '매수'],
#   ['오미', '고점', '돌파'],
#   ['학식', '용돈'],
#   ['고점', '돌파'],
#   [],
#   ['고고'],
#   ['운지', '예정'],
#   ['도지', '고점', '돌파'],
#   ['고점', '돌파'],
#   [],
#   ['오미', '웃음기', '돌아', '개추'],
#   ['오미', '매집', '거래량', '오늘'],
#   [],
#   ['내년', '분기', '세계', '최초', '원격', '의료', '플랫', '출시', '의료', '서비스'],
#   ['부처', '등등', '지지', '기반'],
#   ['세력', '와사', '바리', '아오'],
#   ['에이다', '오늘'],
#   ['업소', '녀랑', '결혼', '현금', '전자'],
#   ['여동생', '거실'],
#   ['오늘', '도지', '산책'],
#   ['운전수', '사납', '위아래', '구조', '마냥', '떠안', '자원', '봉사자'],
#   ['아이오',
#    '에스티',
#    '오',
#    '근데',
#    '지금',
#    '맞음',
#    '도지',
#    '이틀',
#    '다음',
#    '아서',
#    '나락',
#    '이상',
#    '박이'],
#   [],
#   ['버프', '호재', '매집', '지네'],
#   ['컨퍼런스', '그거', '재료', '소멸', '급락', '에이다', '지금', '상투', '냄새'],
#   ['오미', '세'],
#   ['소다',
#    '코인',
#    '급락',
#    '매도',
#    '차트',
#    '확인',
#    '차트',
#    '확인',
#    '미친놈',
#    '시장',
#    '매도',
#    '아서',
#    '강제',
#    '급락',
#    '원대',
#    '매수',
#    '타이밍',
#    '맞음',
#    '최소',
#    '기존'],
#   ['가지', '코인', '그램', '모체'],
#   [],
#   ['새끼', '차트', '보단'],
#   ['짱깨', '머니', '사람', '개추'],
#   [],
#   ['미세'],
#   ['웃기', '쉐', '다음', '유의', '확률', '아서', '유의'],
#   ['오미', '세', '구조', '대오'],
#   ['배때지', '쑤', '오미', '매도'],
#   ['원래', '운전', '코인', '지갑', '담기', '보', '놀'],
#   ['원전'],
#   ['매력', '이유', '주워먹', '기분'],
#   ['어제', '미친년', '소다', '다년', '오늘', '하재', '오늘', '하루', '따먹'],
#   [],
#   ['만달'],
#   ['게임', '실화'],
#   ['관심', '려고', '애쓰', '갓양'],
#   ['매수', '고고'],
#   ['평균', '시드', '실화'],
#   ['마스크', '약속'],
#   ['오늘', '종목', '소다', '개꿀', '소다'],
#   ['운지'],
#   ['오미', '오늘', '세력'],
#   ['버프', '절대', '새기', '아침', '올리', '악질'],
#   [],
#   ['오미', '차트', '예쁘'],
#   ['입금', '농협', '증권', '계좌', '가능', '나'],
#   ['요즘', '제일', '크롬', '코인', '크롬', '협업'],
#   ['일전', '뉴스', '한데', '폴라리스'],
#   ['고점'],
#   ['오미'],
#   ['버프', '사라'],
#   ['마스크', '조정', '매수'],
#   ['풀발', '분전', '오늘', '저녁', '안착', '거래', '채결'],
#   [],
#   ['오미', '세', '때문', '어제', '눈물', '개추'],
#   ['신세', '시발'],
#   ['평단', '전재', '월요일', '센트', '다제'],
#   ['보통', '남자', '대여자', '싸우', '번은'],
#   [],
#   ['손절', '조금'],
#   [],
#   ['어미'],
#   ['선동', '시벌', '도개'],
#   ['고맙', '계약'],
#   ['깨', '보이', '저점'],
#   ['매도'],
#   ['왁스', '토큰', '게임', '순위', '위안', '왁스', '얼마'],
#   ['오미', '하여간'],
#   ['토막', '코인', '시작'],
#   ['버프', '리니어', '병신', '코인'],
#   ['차트', '무섭'],
#   ['엔진', '코인', '움직이', '발련'],
#   ['부럽', '한데', '일상', '생활', '조금', '조금', '계속', '편하'],
#   ['패딩', '살돈', '식충'],
#   ['상승', '장문', '주의'],
#   ['오미',
#    '세',
#    '운전수',
#    '개씹',
#    '고수',
#    '역시',
#    '운전',
#    '수다',
#    '시발',
#    '이거',
#    '모르',
#    '새끼',
#    '패닉',
#    '시드'],
#   ['이번', '주말'],
#   [],
#   ['폴라리스', '해제'],
#   ['이번', '완전', '헛다리', '비트', '이상', '느낌'],
#   ['드', '야지'],
#   [],
#   ['월요일', '상장', '월요일', '다빗'],
#   ['오미', '여기', '이유'],
#   ['언제'],
#   ['손절'],
#   ['글쓴이', '월일'],
#   ['비아', '달'],
#   ['바이',
#    '비트',
#    '실현',
#    '손익',
#    '포스트',
#    '원래',
#    '평단',
#    '보',
#    '수수',
#    '돌려받',
#    '아서',
#    '계속',
#    '손해'],
#   ['폴라리스', '주식'],
#   ['구나',
#    '수수료',
#    '장기',
#    '가지',
#    '무빙',
#    '횡보',
#    '생각',
#    '지금',
#    '거래',
#    '금액',
#    '수수료',
#    '계산',
#    '구나'],
#   ['코인', '일요일', '코인'],
#   ['거래', '대금', '전체', '조원', '거래', '대금', '느낌', '거래', '대금'],
#   ['미세', '어제', '손절'],
#   ['코인', '움짤'],
#   ['오미',
#    '세',
#    '광기',
#    '새끼',
#    '광기',
#    '위로',
#    '아래',
#    '광기',
#    '오늘',
#    '이렇',
#    '내일',
#    '광기',
#    '기다리',
#    '조심'],
#   ['왁스', '평단'],
#   ['헬륨', '새끼', '보이'],
#   ['월요일', '상장', '후회', '정도', '센트', '유출', '원화', '상장'],
#   ['경주마', '버리', '개미'],
#   ['차트', '괜찮', '가볍', '억만'],
#   ['상장', '최저', '바닥', '움직이'],
#   ['보라', '평단', '언제', '탈출'],
#   ['어미', '사라', '병신', '오늘', '전고'],
#   ['엔진', '코인', '운전기사', '악랄', '새끼', '이'],
#   ['플레이', '사도'],
#   ['광고', '평단', '안타깝'],
#   ['거래', '대금'],
#   ['엔진', '코인', '절대', '기사', '악랄', '새끼'],
#   ['바운스', '마시'],
#   ['차트'],
#   ['안산', '흑두', '김치'],
#   [],
#   ['그런데', '질문', '원래', '이렇', '거래', '대금'],
#   ['장매', '물량'],
#   ['탑승', '이유', '사면', '그때', '매수', '타점'],
#   ['아도', '가격'],
#   ['고점', '돌파'],
#   ['시벌', '계속', '저점', '동안', '느낌', '조금'],
#   ['주식',
#    '패가망신',
#    '사람',
#    '특징',
#    '종목',
#    '게시판',
#    '거림',
#    '물리',
#    '근데',
#    '세력',
#    '탈출',
#    '기회',
#    '지금',
#    '계속',
#    '급등',
#    '본전',
#    '근처',
#    '수익',
#    '매도',
#    '수익',
#    '짜증',
#    '개미',
#    '털기',
#    '주일',
#    '본전',
#    '매도',
#    '후회',
#    '결국',
#    '제일',
#    '저점',
#    '눈물',
#    '손절'],
#   ['지독', '지독', '발련', '일동', '퍼먹', '기회비용', '발련'],
#   [],
#   ['주식', '개념', '가능'],
#   ['타점'],
#   ['거래', '대금'],
#   ['건가', '가망', '알'],
#   ['나락', '시발'],
#   ['승리'],
#   ['골반'],
#   ['누사', '사라'],
#   ['오늘', '딜러', '영업', '한데', '휴무일'],
#   ['오후', '경주마', '예상'],
#   ['거래', '대금', '동안', '인치', '도지', '등등'],
#   ['이거', '호재'],
#   ['월요일', '상장', '이유', '원간'],
#   ['엔진', '가보', '손절', '라인'],
#   ['박이'],
#   [],
#   ['끝', '개추'],
#   ['비트', '오', '라면', '하방', '현금', '관망', '심판'],
#   ['손익'],
#   ['시작', '근데', '시발', '대출'],
#   ['엔진', '보이'],
#   ['긴급', '속보', '오비', '글로벌', '마진', '상장', '지금'],
#   [],
#   ['오미'],
#   ['에이다'],
#   ['평단'],
#   ['발표', '시간'],
#   ['골반'],
#   ['엔진', '쌍고', '하방', '지금'],
#   ['사고', '등주', '경주마', '단기'],
#   ['튜브', '사라', '저점', '야무지', '물량', '확보', '완료'],
#   ['오늘', '재미없'],
#   ['오미', '병신'],
#   [],
#   ['왁스', '사고', '오늘'],
#   ['엔진', '오후'],
#   ['동력'],
#   ['이거'],
#   ['병신', '횡보'],
#   ['전성기', '지금', '보', '재밌'],
#   ['폴라리스', '김치', '코인'],
#   ['발표', '확률'],
#   ['대체'],
#   ['지금'],
#   ['평단'],
#   ['오미', '세', '지갑', '언제', '닫'],
#   ['장담', '오미', '세', '내일'],
#   ['진정', '고수', '지금', '코인'],
#   ['다음',
#    '행보',
#    '기대',
#    '디비전',
#    '이번',
#    '프리',
#    '본격',
#    '시장',
#    '진출',
#    '공시',
#    '면',
#    '베타',
#    '가상',
#    '콘서트',
#    '개최',
#    '기대'],
#   ['은지'],
#   ['에이다'],
#   ['중력'],
#   ['디비전', '차이', '코인', '탑승', '손절', '디비전', '타도'],
#   ['고체', '상태'],
#   ['비트'],
#   ['평단'],
#   ['본인', '이번', '공기'],
#   ['정도', '수익', '자랑'],
#   ['근데', '등주', '상장주', '물리', '나머지'],
#   ['실시', '오미', '세', '상황'],
#   ['미아', '근황', '광신도', '몰리'],
#   ['갈만', '어제'],
#   ['언제'],
#   ['중력'],
#   ['가치', '투자자', '승리', '시간'],
#   ['지금'],
#   ['진심', '코인', '대장', '리플', '에이다', '에이다'],
#   ['오늘', '약속', '치', '매수'],
#   ['상장',
#    '상장',
#    '코인',
#    '판타지',
#    '코인',
#    '신박',
#    '중고',
#    '거래',
#    '핵심',
#    '파트너',
#    '미션',
#    '이나',
#    '광고',
#    '시청',
#    '물품',
#    '올리',
#    '코인',
#    '추후',
#    '정도',
#    '규모',
#    '상장',
#    '가능',
#    '모아'],
#   ['평단'],
#   ['놀', '호재', '배포', '놀', '공식', '쿠폰', '메세지', '배포', '방금', '개떡', '상한', '저녁'],
#   ['도지'],
#   ['옘병', '코인'],
#   ['시국', '선물', '리스크'],
#   ['코인', '전부'],
#   ['치킨'],
#   ['시발'],
#   [],
#   ['포스', '코인', '포스', '창업자', '친환경', '코인'],
#   ['중력'],
#   ['시드', '어도', '전한', '전업', '가능', '한데'],
#   ['의무',
#    '따르',
#    '보상',
#    '지급',
#    '나라',
#    '근본',
#    '군대',
#    '아무',
#    '세금',
#    '이유',
#    '세금',
#    '쓰이',
#    '리스크',
#    '사회',
#    '보장',
#    '혜택',
#    '믿음',
#    '때문',
#    '근데',
#    '군대',
#    '의무',
#    '강요',
#    '개인',
#    '자유',
#    '모두',
#    '빼',
#    '국방',
#    '의무',
#    '이름',
#    '하나',
#    '신체',
#    '정신',
#    '착취',
#    '따르',
#    '보상',
#    '체제',
#    '존재',
#    '보상',
#    '의무',
#    '책임',
#    '희생',
#    '강요',
#    '지탱',
#    '요소',
#    '일부',
#    '인간',
#    '심리',
#    '경쟁',
#    '심리',
#    '이용',
#    '정당',
#    '부여',
#    '군대',
#    '시스템',
#    '사회',
#    '단절',
#    '합리',
#    '처우',
#    '내밀',
#    '나간',
#    '군인',
#    '존재',
#    '항의',
#    '윗대',
#    '가리',
#    '이해관계',
#    '의하',
#    '묵살',
#    '보상',
#    '책임감',
#    '유도',
#    '의무',
#    '따르',
#    '보상',
#    '지급'],
#   ['오늘', '횡보'],
#   ['성대', '지리', '고요'],
#   ['오미', '세', '이해', '사람', '지금', '마이너스', '이거', '어떻'],
#   ['리니어'],
#   ['새기', '무빙', '좆같', '저녁', '평단', '대장', '병신', '화난'],
#   ['껄떡대', '호재', '반영'],
#   ['미아', '오늘', '하이', '무보', '자무', '역시', '믿음', '미아', '오늘', '은총'],
#   ['미아'],
#   ['역대', '저점', '역대', '고점', '개추'],
#   ['양전'],
#   ['손절', '오'],
#   ['역시', '주말', '발노'],
#   ['손절'],
#   ['이번', '디비전', '월드', '공식', '출범', '추가', '상장', '파트너', '호재', '진입'],
#   ['사고'],
#   ['무빙', '멀미', '조금', '저점'],
#   ['시발', '조정', '발련'],
#   ['불장'],
#   ['발표', '오늘', '내용'],
#   ['여자', '항문', '섹스', '가능', '가능', '세요'],
#   ['거지', '거지', '거지', '떨어지'],
#   ['중력'],
#   ['왁스', '사고', '미침'],
#   ['하루'],
#   [],
#   ['언제', '따라잡'],
#   ['리니어', '오늘', '금사'],
#   [],
#   ['힘드', '등주', '빠', '도박사', '물리'],
#   ['소다', '평단', '탈출', '가능', '미치', '큰일'],
#   ['갓네', '쓰레기'],
#   ['중력', '배반'],
#   ['기회', '비체', '매수'],
#   [],
#   [],
#   ['각수렴'],
#   ['새벽', '미아'],
#   ['횡보'],
#   ['돌파', '기원', '개추'],
#   ['엔진', '탈출', '가능'],
#   ['코인', '병신', '새끼', '정신', '승리'],
#   ['타운', '사람'],
#   ['대장', '개추', '시바'],
#   ['세력', '개미', '죽인', '다음', '독한', '몇일', '지랄'],
#   ['남자', '코인'],
#   ['리니어', '동안'],
#   ['프로토콜'],
#   ['지금', '연말'],
#   ['바운스', '고고'],
#   ['느낌', '느낌'],
#   ['리니어', '예전', '사람', '지금', '사람', '환장'],
#   ['포트폴리오', '가능'],
#   ['가격', '유지', '언제'],
#   ['엔진', '언제', '매도', '치지'],
#   ['언급', '느리', '재미없', '근가', '지리'],
#   ['매도', '매도'],
#   ['오비', '글로벌', '상장'],
#   ['홀더', '홀더', '저점', '홀더', '병신', '고점', '홀더', '저점', '홀더', '시발'],
#   ['고수'],
#   ['오징어', '게임', '지금', '사고', '부자'],
#   ['하나', '추천'],
#   [],
#   ['오미', '세', '느낌', '고점'],
#   ['오늘', '얼마'],
#   ['지금', '보임', '저녁', '새벽', '도전'],
#   ['횡보', '목표'],
#   ['리니어', '감사', '오늘'],
#   ['오늘', '세력', '단말', '루머'],
#   ['머스크', '도지', '관계'],
#   ['어떻', '모르', '어울리'],
#   ['리니어', '파이낸스', '이유'],
#   ['시드'],
#   ['애무'],
#   ['리니어', '바운스'],
#   ['리니어', '새끼', '병신', '사람', '인생', '개씹'],
#   ['리니어', '선동', '선동', '당하'],
#   ['홀더', '차트', '오', '차트'],
#   ['분봉', '차트'],
#   ['미아'],
#   ['욕', '선동', '얼른', '선동', '떨어지', '반복', '아서'],
#   ['스택'],
#   ['진심'],
#   ['라미', '남자', '테스트'],
#   ['오늘', '고점', '이렇', '비실', '애무'],
#   ['직원', '운영', '유료', '다음', '원화', '상장', '후보', '시바', '인파', '코인', '이렇', '얘기'],
#   ['폴카', '역시', '전자'],
#   ['리니어', '사카'],
#   ['리니어', '파이낸스', '이유', '시간', '퍼먹', '엇다'],
#   ['리니어', '리니어'],
#   ['코인', '모르', '폴카', '오미', '세', '엔진', '코인', '고사', '개월'],
#   ['저거', '이상', '조심'],
#   ['미아'],
#   ['시드', '행복'],
#   ['글리'],
#   ['청산', '청산', '청산'],
#   ['후기'],
#   ['버프'],
#   ['때문', '스트레스', '자식'],
#   ['플라스틱', '이거', '전자', '렌지'],
#   ['이번', '원화', '상장', '후보', '시바', '인파', '코인', '맹신'],
#   ['리니어', '루프', '매수', '루프'],
#   ['저거', '망부석'],
#   ['승률', '프로', '지껄이', '하나', '제이'],
#   ['대선', '여론', '조사'],
#   ['우리', '호구', '오늘'],
#   ['근데',
#    '비트',
#    '극소수',
#    '코인',
#    '저점',
#    '무릎',
#    '정도',
#    '아도',
#    '수익',
#    '그동안',
#    '고체',
#    '버프',
#    '이렇',
#    '다섯',
#    '저점'],
#   ['근데', '누나', '성인', '누나'],
#   ['고수', '지금'],
#   ['부모', '부양', '무주택', '수저', '중산', '전이'],
#   ['병신',
#    '새끼',
#    '협업',
#    '코인',
#    '병신',
#    '정보',
#    '올리',
#    '동당',
#    '손절',
#    '버프',
#    '응신',
#    '차트',
#    '보',
#    '버프',
#    '병신',
#    '어제',
#    '지금',
#    '수익',
#    '구간',
#    '차트',
#    '시작',
#    '그리고',
#    '추세',
# ...
#    '마진',
#    '거래',
#    '보이',
#    '싸움',
#    '지속',
#    '할론',
#    '데이',
#    '이후',
#    '청산',
#    '당한',
#    '블랙',
#    '머니',
#    '오보',
#    '뉴스',
#    '물량',
#    '철수',
#    '항복',
#    '선언',
#    '시바',
#    '달러',
#    '예상',
#    '이후',
#    '환율',
#    '변동',
#    '각국',
#    '달러',
#    '상응',
#    '물가',
#    '기준',
#    '등등',
#    '포함',
#    '정책',
#    '달러',
#    '표기',
#    '기준',
#    '금액',
#    '도지',
#    '사용',
#    '생활',
#    '거래',
#    '암호',
#    '화폐',
#    '지향',
#    '시바'],
#   ['에이다', '마디', '코인', '코인', '인기'],
#   ['아파트', '오늘', '얼른', '매수', '지금', '완전', '저점'],
#   ['사람'],
#   [],
#   ['새끼'],
#   ['근데',
#    '자체',
#    '월렛',
#    '개발',
#    '무산',
#    '암호',
#    '화폐',
#    '사용',
#    '무산',
#    '월렛',
#    '암호',
#    '화폐',
#    '사용',
#    '악재',
#    '한데',
#    '폭락',
#    '정도'],
#   ['도지'],
#   ['길드', '안보'],
#   ['퇴근', '마스크', '달러'],
#   ['도지', '분전'],
#   ['에이다', '이비', '에이다', '짜증', '코인'],
#   ['멍청이'],
#   ['화성', '자체', '사기', '화성', '자기장', '애초', '인간'],
#   [],
#   ['시작', '튜브'],
#   ['튜브', '얼마', '가능'],
#   ['벤드', '무조'],
#   ['저점', '상승', '지금', '병신', '오', '저점', '상승', '추세', '코인', '고서', '지금', '병신'],
#   ['저항선', '정도', '계산'],
#   [],
#   ['튜브'],
#   ['특징', '아서', '무섭', '계속', '아프', '잉신'],
#   ['오미', '세', '일봉', '느낌'],
#   [],
#   ['지금', '수익', '줄때', '본전', '날', '손절', '나감'],
#   ['오늘', '역대', '불장'],
#   ['스타'],
#   ['발아', '커플링'],
#   ['도지'],
#   ['루프', '봉호', '섹스', '출발'],
#   ['아야',
#    '코인',
#    '가지',
#    '도지',
#    '무한',
#    '발행',
#    '코인',
#    '가치',
#    '수렴',
#    '코인',
#    '유행',
#    '이유',
#    '하나',
#    '현재',
#    '가격',
#    '코인',
#    '코인',
#    '무한',
#    '가능',
#    '시간',
#    '하루',
#    '공짜',
#    '코인',
#    '마찬가지',
#    '공짜',
#    '코인',
#    '휴사',
#    '포인트',
#    '공짜',
#    '코인',
#    '이것',
#    '가스',
#    '사면',
#    '배당금',
#    '코인',
#    '보너스',
#    '코인',
#    '개념',
#    '마다',
#    '코인',
#    '개수',
#    '가스'],
#   ['튜브', '반가'],
#   ['고점', '새끼', '뚫리', '거리', '새끼'],
#   ['마스크', '스타', '호재', '모두', '예상', '대로'],
#   ['무섭'],
#   ['레버리지', '천추', '청산', '당하', '지금', '시발'],
#   ['바보',
#    '도지',
#    '월렛',
#    '악재',
#    '사실',
#    '그리고',
#    '선물',
#    '개념',
#    '김치',
#    '코인',
#    '도지',
#    '대가리',
#    '그렇',
#    '시드',
#    '인증',
#    '아서',
#    '청산'],
#   ['어디', '시벌'],
#   ['시바', '버터', '아야', '정답', '스트레스', '개이'],
#   ['어제', '바이', '선물', '사람'],
#   ['튜브', '고고'],
#   ['버프', '랠리', '마로', '역시', '추천인', '이벤트', '해묵', '홀더', '석우', '소장'],
#   [],
#   ['프로'],
#   ['심상'],
#   ['대가리',
#    '도지',
#    '나락',
#    '선물',
#    '거래소',
#    '김치',
#    '코인',
#    '이나',
#    '나락가',
#    '거지',
#    '개병',
#    '신년',
#    '좆',
#    '새끼',
#    '코인'],
#   ['상식', '코인', '장애', '우가', '설마'],
#   [],
#   ['려고', '츄리닝', '무시', '일시불', '나이', '촌티', '려고', '무시', '은행'],
#   ['튜브', '시작', '인감'],
#   ['케이', '사람', '양전'],
#   [],
#   ['악지', '악질'],
#   ['하나', '자'],
#   ['오비', '나락가', '저점', '하', '하나'],
#   ['질문', '선물', '이거', '직위', '저렇', '어디', '모르'],
#   [],
#   ['폭락'],
#   ['시작', '튜브', '고고'],
#   ['평단'],
#   ['마스크', '나락'],
#   ['하인', '수익', '줄때', '수익', '줄때', '본전'],
#   ['지금'],
#   ['실시간', '도지', '근황'],
#   ['다음'],
#   ['잔치'],
#   ['체인', '링크', '타점'],
#   ['현재', '시간'],
#   ['루프', '저항'],
#   ['손실'],
#   ['클럽', '나락'],
#   ['길드', '호재'],
#   [],
#   ['꼬', '지령', '개미', '모이', '추매', '주말'],
#   ['루프', '그럼', '게임', '스톱'],
#   ['호재'],
#   ['아르고', '아르고'],
#   ['여기'],
#   ['한단', '삭제'],
#   ['다음', '아르고'],
#   ['오징어', '마스크', '지랄', '어디', '이나'],
#   ['어제', '그렇', '마스크', '나락'],
#   ['어떻'],
#   ['현재', '코인'],
#   ['루프', '매도', '쳐먹', '병신', '세력'],
#   ['설마', '저항'],
#   ['스타', '아르고', '협업', '아르고'],
#   ['욕심', '부리', '세요', '저항', '순식간'],
#   ['길드', '이유', '정리'],
#   ['좆같', '아서'],
#   ['길드', '연관'],
#   ['다음', '아르고'],
#   ['니어', '폭주', '아들', '근데', '개미'],
#   ['협업', '아르고'],
#   ['로그인', '이거', '문자'],
#   ['수익',
#    '어렵',
#    '코인',
#    '그거',
#    '수익',
#    '보이',
#    '전하',
#    '매매',
#    '이벤트',
#    '찾아다니',
#    '한데',
#    '이랑',
#    '친구',
#    '초대',
#    '이벤트',
#    '가족',
#    '명의',
#    '친구',
#    '부탁',
#    '추천인',
#    '품앗이',
#    '나쁘',
#    '보이',
#    '이거',
#    '최대한',
#    '나중',
#    '상장'],
#   ['여기', '사람'],
#   ['아르고', '아아'],
#   ['협업', '아르고', '아아', '스타'],
#   ['고통'],
#   ['마스크', '지금', '손절'],
#   ['도지', '알아보', '조정', '트윗', '무시', '지금', '대박', '기회', '에이다', '도지', '합병', '호재'],
#   ['흑우', '시기', '질투'],
#   ['며칠', '동안', '비비', '원정'],
#   ['선동', '새끼', '시드', '병신', '시장', '영향', '개병', '새끼', '이거', '저거', '사라', '개지랄'],
#   ['도지', '평단', '손절', '천만', '지견'],
#   [],
#   ['방법',
#    '아치',
#    '루트',
#    '요즘',
#    '진행',
#    '사항',
#    '최근',
#    '느끼',
#    '고질',
#    '유동',
#    '문제',
#    '게임',
#    '레벨',
#    '아이템',
#    '변경',
#    '가능',
#    '대박',
#    '디자인',
#    '부분',
#    '수정',
#    '마지막',
#    '동접',
#    '이나',
#    '정도',
#    '게임',
#    '구성',
#    '시스템',
#    '멀티',
#    '플레이',
#    '모드',
#    '보물',
#    '박스',
#    '시스템',
#    '신규',
#    '자체',
#    '개발',
#    '플레이스',
#    '확인',
#    '기대',
#    '열리',
#    '정도'],
#   ['인생', '보단', '매수', '난리'],
#   ['길드', '호재'],
#   ['시드', '작년', '토막', '회복'],
#   ['종목'],
#   ['발련', '언제'],
#   ['타', '조짐'],
#   ['도지', '폭락'],
#   ['길드', '오늘', '어디'],
#   ['붕이', '생각', '전망', '어떻', '생각', '생태', '테마', '게이', '생각'],
#   [],
#   ['오늘', '마스크', '호구'],
#   ['오늘', '코인', '아르고'],
#   ['사려',
#    '테스트',
#    '한데',
#    '저점',
#    '연어',
#    '조심',
#    '연어',
#    '보',
#    '새끼',
#    '너희',
#    '망하',
#    '상관없',
#    '한데',
#    '망하',
#    '인생',
#    '지름길',
#    '망하'],
#   ['길드', '매수세'],
#   ['길드', '오늘', '프로'],
#   ['악재', '타격', '이유', '김치', '코인', '상장', '세력', '김치', '세력', '개념'],
#   ['오늘', '천기누설', '코인', '길드'],
#   ['호재', '장난', '모건', '선택', '테스트', '진행', '상용', '화감', '수익', '호재', '검색'],
#   [],
#   ['하', '협업', '아르고', '코인'],
#   ['마스크', '번지'],
#   ['벽력', '일섬', '기도', '개추'],
#   ['메타', '메타', '보이'],
#   ['질문'],
#   [],
#   ['도지', '새끼', '도지', '부추기', '선동'],
#   ['준비'],
#   ['어제', '마스크', '취소', '잠결'],
#   ['머스크', '트윗', '얘기'],
#   ['메타', '메타', '동네', '구멍가게', '보이'],
#   ['내일', '계속', '특급', '호재', '보이'],
#   ['지금', '비트', '게이', '전진', '고급', '정보', '부자', '거', '불안', '로스', '돌격'],
#   ['이', '지금', '매수'],
#   ['머스크', '트윗', '자아'],
#   ['머스크', '컴백', '오예'],
#   ['매수', '시점', '지금'],
#   ['버거', '타임', '판단', '붕이', '여기', '매수', '수익'],
#   [],
#   ['마스크'],
#   ['절대', '연어', '무빙', '절대', '기부'],
#   ['호재', '장난', '시인', '가능'],
#   ['루프', '원상', '가능', '유력'],
#   ['도지', '호재', '얼른', '트윗'],
#   ['마스크'],
#   ['생각'],
#   ['불나방'],
#   ['추세',
#    '괜찮',
#    '비트',
#    '빠',
#    '전체',
#    '나락',
#    '생각',
#    '보',
#    '다행',
#    '횡보',
#    '가격',
#    '대하',
#    '올인원',
#    '플랫',
#    '최근',
#    '네트워크',
#    '변경',
#    '인프라',
#    '확장',
#    '추가',
#    '상장',
#    '기대감',
#    '추세',
#    '괜찮'],
#   ['속보', '머스크', '이상', '뿌리', '박멸', '기대'],
#   ['마스크', '바닥', '주도', '코인', '방금', '바닥', '진입'],
#   ['니', '채소'],
#   ['어제'],
#   ['도지', '도라지', '직전', '탈출'],
#   ['오늘', '어미'],
#   ['연말', '랠리'],
#   ['머스크', '암말'],
#   ['가능', '시발'],
#   ['오늘', '자정', '도지', '바라'],
#   ['도지', '새끼', '아서'],
#   ['모지리', '코인'],
#   ['버거', '타임', '오늘', '당장', '내일', '모건', '가지', '짓거리'],
#   ['언제', '머스크', '지견', '지망', '머스크', '신경'],
#   ['머스크',
#    '코인',
#    '개발',
#    '포기',
#    '이',
#    '인수',
#    '하루',
#    '뒤집',
#    '인물',
#    '코인',
#    '지갑',
#    '개발',
#    '머스크',
#    '근데',
#    '트윗',
#    '코인',
#    '관련',
#    '아무것',
#    '머스크',
#    '공지'],
#   ['어디',
#    '미치',
#    '어제',
#    '고민',
#    '새끼',
#    '원망',
#    '스럽',
#    '메타',
#    '버스',
#    '마소',
#    '세계',
#    '기업',
#    '메타',
#    '버스',
#    '느낌',
#    '리플렉스',
#    '기대',
#    '국내',
#    '기업',
#    '기술력',
#    '보장',
#    '파트너',
#    '사나',
#    '고객',
#    '사도',
#    '이름',
#    '정도',
#    '메타',
#    '버스',
#    '지리',
#    '매매',
#    '기회',
#    '아서',
#    '찾',
#    '이거',
#    '준비',
#    '괜찮',
#    '보이'],
#   ['새끼', '고맙', '착하', '그래서', '도지'],
#   ['지충', '악재', '머스크', '수고'],
#   ['생각', '인수', '답답이'],
#   ['마스크', '개창', '현자'],
#   ['세계', '은행', '모건'],
#   ['매물', '건가'],
#   ['아파트', '흑우'],
#   ['지견', '머스크', '강아지', '티셔츠', '꼴', '새기'],
#   ['부럽'],
#   ['지금', '수익', '까먹', '새끼', '특징'],
#   ['하나', '성지'],
#   ['체인', '링크', '시발', '지금'],
#   ['메타', '메타', '동네', '구멍', '거'],
#   ['속보', '대박', '호재', '풀매', '수박', '도지', '코인', '지롱'],
#   ['거래', '대금', '단위', '세계', '은행', '모건', '그것', '찐하'],
#   ['디지털', '장선', '암살', '당하', '하'],
#   ['아서', '병신', '만가'],
#   ['미스', '블록', '이렇', '병신', '호재'],
#   ['하', '협업', '아르고', '코인'],
#   ['머스크', '새끼', '아야', '도전'],
#   ['마스크', '보', '떨어지', '당신', '최고', '구라', '쳐먹', '마다', '재미', '지네'],
#   ['성대', '시작'],
#   ['머스크', '트윗'],
#   ['경주마', '저녁'],
#   ['아르고', '직전'],
#   ['하', '기업', '협업', '코인', '아르고'],
#   ['세계', '위부'],
#   ['아르고', '선동'],
#   ['세계', '위인', '도전장'],
#   ['세계', '최고', '부자', '도전장', '일반인', '개기', '똑같'],
#   ['일반인', '맞짱', '자', '도지'],
#   ['코스모스'],
#   ['일반인', '까보', '자'],
#   ['오디', '우스', '응기'],
#   [],
#   ['아파트', '얼른'],
#   ['도지'],
#   ['노예', '조선족', '노가다', '일당', '버러지', '도전장'],
#   ['아크', '어덕', '탈출', '버러지', '코인'],
#   ['도지', '염병', '진짜'],
#   ['도전장', '도지', '인생', '미안'],
#   ['여기', '도배', '사람'],
#   ['메타', '버스', '일봉', '이랑', '도지', '일봉', '비교'],
#   ['일반인', '효도', '맞짱', '자'],
#   ['에이다', '평단'],
#   ['도지', '언제'],
#   ['일용직', '노가다', '잡부', '버러지', '인생', '도전장'],
#   ['아르고', '빙신'],
#   ['노가다', '인생', '세계', '위인', '도전장'],
#   [],
#   ['마조', '히스', '털리', '계속', '도지', '저배', '치', '각자'],
#   ['도지',
#    '올해',
#    '원가',
#    '내년',
#    '도지',
#    '가지',
#    '그때',
#    '똑같',
#    '동안',
#    '도지',
#    '원일',
#    '저점',
#    '판단',
#    '바닥',
#    '무릎',
#    '기다리',
#    '지금',
#    '방금',
#    '이거',
#    '생각',
#    '산당',
#    '상관없',
#    '내년',
#    '겨울',
#    '그리고',
#    '이거',
#    '주식',
#    '코인',
#    '만지',
#    '주식',
#    '삼전',
#    '재산',
#    '삼전',
#    '이랑',
#    '도지',
#    '코인',
#    '내년',
#    '겨울',
#    '내년',
#    '상반기',
#    '부동산',
#    '주식',
#    '계속',
#    '하반기',
#    '기다리',
#    '금쪽',
#    '타이밍',
#    '아서',
#    '모두',
#    '화이'],
#   ['근데'],
#   [],
#   ['스타', '지원', '기사'],
#   ['익현', '어도', '구독자', '보통', '수천만', '이상'],
#   ['야간',
#    '돌',
#    '여자',
#    '여자',
#    '애인',
#    '기억',
#    '오늘',
#    '보',
#    '국문학',
#    '재밌',
#    '물건',
#    '내려놓',
#    '세요',
#    '안녕',
#    '세요'],
#   ['도지', '도지', '저녁', '최소', '인생', '절호', '찬스'],
#   ['매수'],
#   ['도지', '조정', '지금', '거러지'],
#   ['다면', '아무것', '포기', '이브', '커플', '시발'],
#   ['도지'],
#   ['도지',
#    '시작',
#    '암호',
#    '화폐',
#    '지갑',
#    '개발',
#    '중단',
#    '바이',
#    '지원',
#    '필요',
#    '만드',
#    '선동',
#    '후드',
#    '물량',
#    '바이',
#    '후회',
#    '프로',
#    '호들갑',
#    '연말'],
#   ['개꿀', '사라', '면', '기회'],
#   ['아도', '지사서', '부모', '용돈', '백수'],
#   ['케이'],
#   ['개꿀'],
#   ['타이탄', '대호'],
#   ['기모', '기모'],
#   ['어제', '마스크', '케이', '하나', '고민'],
#   ['머스크', '성향', '연말', '선물', '보따리', '기모', '연말', '야지'],
#   ['메타',
#    '호재',
#    '정리',
#    '공개',
#    '붕이',
#    '고',
#    '세계',
#    '최초',
#    '테스트',
#    '성공',
#    '메타',
#    '테라',
#    '몰락',
#    '개발',
#    '프로젝트',
#    '유입',
#    '공동',
#    '창업자',
#    '암호',
#    '화폐',
#    '예정',
#    '은행',
#    '경찰',
#    '레닛',
#    '협약',
#    '레닛',
#    '협약',
#    '스타',
#    '등등',
#    '정도',
#    '지금',
#    '최소',
#    '이상',
#    '아야'],
#   ['도지', '만언', '개꿀'],
#   ['건방지', '세계', '위인', '도전장', '건방지', '세계', '위인', '도전장'],
#   ['문제',
#    '제목',
#    '아로와나',
#    '클릭',
#    '오픈',
#    '소스',
#    '검증',
#    '가능',
#    '오픈',
#    '소스',
#    '프로젝트',
#    '보',
#    '프로젝트',
#    '가황',
#    '계속',
#    '검증',
#    '문제',
#    '현재',
#    '거래',
#    '기사',
#    '싸지르',
#    '세력',
#    '환장'],
#   ['도지'],
#   ['시발', '시간', '다음', '음전', '손절'],
#   ['디시', '새끼', '거지새끼', '거지', '안타깝', '추천', '마스크', '시발'],
#   ['다리', '핫바지', '거지'],
#   ['도지', '확정', '세력', '드', '내일'],
#   ['다리', '핫바지', '보이'],
#   ['마스크'],
#   ['친구', '비트', '재산'],
#   ['월드컵', '랜드', '시동', '관심'],
#   ['세계', '위부', '도전장'],
#   ['폭락', '도지', '보임', '진돗개'],
#   ['세계',
#    '도전장',
#    '일용직',
#    '노예',
#    '세계',
#    '도전장',
#    '일용직',
#    '노예',
#    '노가다',
#    '일용직',
#    '바리',
#    '새끼'],
#   ['도지', '결제', '가능', '새끼'],
#   ['병신', '시작'],
#   ['도지', '지금', '세계'],
#   ['세계', '도전장', '세계', '도전장', '일용직', '노예', '노가다', '일용직', '바리', '새끼'],
#   ['도지', '결제', '가능', '구라'],
#   ['도지'],
#   ['도지', '오', '이유', '머스크', '트윗'],
#   ['마스크', '시바'],
#   ['모지리',
#    '도지',
#    '개미',
#    '털기',
#    '아서',
#    '자격',
#    '도지',
#    '코인',
#    '결제',
#    '허용',
#    '시행',
#    '주전',
#    '거대',
#    '세력',
#    '매집',
#    '일간',
#    '조금'],
#   ['지금', '머스크', '트윗', '난리', '도지', '예정'],
#   ['도지', '떨어지', '전고', '이렇', '소재'],
#   ['나이스', '마스크', '멸망'],
#   ['거러지', '아도', '지능', '개신', '개신', '개신', '어감'],
#   ['도지', '시동'],
#   ['도지', '매력', '맞음', '주식', '매수', '저점', '어도', '메타', '기업', '눈길', '안감'],
#   ['마스크', '머니', '도지', '동중'],
#   ['트윗', '어디', '도지', '결제', '가능', '언급', '지금', '잡음', '보임'],
#   ['마스크', '멸망'],
#   ['마스크'],
#   ['기분', '쇠주먹', '한숨', '확정', '연말'],
#   ['도지', '지금'],
#   ['시발', '도지', '거래', '대금', '오후', '저렇', '올리'],
#   ['도지', '보소', '천만', '손실', '좆같'],
#   ['개미'],
#   ['도지', '오늘', '반', '참고', '야수'],
#   ['실시간', '머스크', '트윗'],
#   ['도지', '오늘', '짜임', '광기', '모르'],
#   ['비트', '조까'],
#   ['도지', '거래', '대금', '확인', '바라', '시간', '억단', '정도', '확인', '머리'],
#   ['오늘', '도지', '양전', '가격'],
#   ['지랄', '도지'],
#   ['개미', '썰리'],
#   ['바이', '최근', '수천억', '장가', '매수', '도지'],
#   ['도지', '시장'],
#   ['머스크', '이미지', '이번', '인수', '이번', '도지', '진심'],
#   ['속보'],
#   ['도지', '타이탄', '급등', '불나방', '안타깝'],
#   ['도지', '새끼'],
#   ['도지', '야수', '시발'],
#   ['도지', '세력', '머스크', '나락', '세력', '모르', '이상', '모르'],
#   ['이번',
#    '도지',
#    '마스크',
#    '어떻',
#    '도지',
#    '분봉',
#    '참고',
#    '시드',
#    '근데',
#    '시드',
#    '평단',
#    '파란',
#    '근데',
#    '쏘',
#    '관망',
#    '여기',
#    '후회',
#    '시드',
#    '근데',
#    '이때',
#    '낮잠',
#    '확인',
#    '아무튼',
#    '수익',
#    '근데',
#    '생각',
#    '보',
#    '하방',
#    '저점',
#    '더블',
#    '상승',
#    '생각',
#    '더블',
#    '반절',
#    '주황',
#    '그리고',
#    '더블',
#    '상승',
#    '하락',
#    '평단',
#    '떨',
#    '여기',
#    '떨',
#    '구간',
#    '구나',
#    '살짝',
#    '조정',
#    '그래서',
#    '생각',
#    '보',
#    '물대',
#    '빠',
#    '구나',
#    '제일',
#    '저점',
#    '더블',
#    '생각',
#    '관망',
#    '초록',
#    '수익',
#    '정도',
#    '달러',
#    '가량',
#    '참고',
#    '도지',
#    '그래프',
#    '마스크',
#    '분봉',
#    '참고',
#    '고점',
#    '조정',
#    '떨어지',
#    '구간',
#    '그리고',
#    '조정',
#    '시작',
#    '저점',
#    '더블',
#    '구간',
#    '여기',
#    '반절',
#    '지켜보',
#    '주황',
#    '매물',
#    '빠',
#    '여기',
#    '빠',
#    '구나',
#    '지켜보',
#    '근데',
#    '마스크',
#    '새끼',
#    '주의',
#    '전날',
#    '지랄',
#    '경력',
#    '고점',
#    '그래서',
#    '반절',
#    '매물',
#    '빠',
#    '그래서',
#    '초록',
#    '발련',
#    '그리고',
#    '지켜보',
#    '빠',
#    '이렇',
#    '매물',
#    '구간',
#    '대충',
#    '반절',
#    '주황',
#    '살짝',
#    '떨어지',
#    '이번',
#    '이렇',
#    '매물',
#    '구간',
#    '초록',
#    '마스크',
#    '정도',
#    '달러',
#    '가량',
#    '댓글',
#    '드림'],
#   ['도지', '매도', '물량', '호구', '득달', '물량'],
#   ['도지'],
#   ['야수', '심장', '묵념', '떨어지'],
#   ['도지', '추락'],
#   ['일용직',
#    '공창',
#    '노가다',
#    '새끼',
#    '머스크',
#    '일용직',
#    '공창',
#    '노가다',
#    '새끼',
#    '머스크',
#    '거부',
#    '잡부',
#    '새끼'],
#   ['하락', '야수', '시발', '시발', '야발', '시발'],
#   ['마스크', '나락'],
#   ['아파트', '약속', '발사', '예정'],
#   ['도지', '개미', '털기', '단기'],
#   ['도지', '오늘', '가능', '보임'],
#   ['머스크', '대량', '해고', '소송'],
#   ['도지', '자식'],
#   ['야수', '심장', '평단', '시발'],
#   ['악재', '어도', '마스크', '코인'],
#   ['김치',
#    '세력',
#    '세력',
#    '곰팡',
#    '원룸',
#    '세력',
#    '새끼',
#    '도지',
#    '도지',
#    '세력',
#    '이랑',
#    '비교',
#    '대상',
#    '자체'],
#   ['지랄', '비트', '새끼'],
#   ['야수', '심장', '고점', '판독기', '야수', '상승', '떨어지', '어중간', '프로', '광고', '고로', '야반'],
#   ['하'],
#   ['튜브'],
#   ['곰팡', '김치', '세력', '도지', '세력', '차원', '닥'],
#   ['도지', '머스크', '사진', '이렇', '호재'],
#   ['저거', '기다리', '느'],
#   ['길드', '파동', '한데'],
#   ['하', '이벤트', '마다', '바닥', '코인'],
#   ['비트', '발련'],
#   ['오', '구나', '오', '물리'],
#   ['도지', '일간', '물량'],
#   ['도지', '에이다', '합병', '소식', '결정', '상상', '자유', '지금'],
#   ['마스크'],
#   ['리플', '소송', '연기'],
#   ['야수',
#    '심장',
#    '코인',
#    '좆같',
#    '보이',
#    '나',
#    '지금',
#    '현재',
#    '포지션',
#    '생각',
#    '좆같',
#    '코인',
#    '하나',
#    '려고'],
#   ['도지', '손절', '친애', '물량', '출격', '준비', '완료', '오늘'],
#   ['도지',
#    '코인',
#    '급락',
#    '암호',
#    '화폐',
#    '월렛',
#    '개발',
#    '중단',
#    '도지',
#    '코인',
#    '급락',
#    '암호',
#    '화폐',
#    '월렛',
#    '개발',
#    '중단',
#    '코인'],
#   ['도지'],
#   ['짱깨', '제로', '해제', '짱깨', '코인', '메타'],
#   ['도지', '계속'],
#   ['도지'],
#   [],
#   ['도지', '바보', '일간', '눈깔', '생선', '눈깔'],
#   ['마스크', '도지'],
#   ['비트'],
#   ['토스', '고래', '흔적', '확인'],
#   ['비탈', '의외', '대로'],
#   ['나롱', '선물', '입', '개월', '비트', '근래', '데마', '나롱'],
#   ['도지'],
#   ['비트', '코스'],
#   ['머스크', '세계', '부자', '도전장', '혼쭐'],
#   ['도지', '양전', '마스크', '양전', '가능'],
#   ['가리', '볶음', '개꿀'],
#   ['휴전', '확정'],
#   [],
#   ['비트', '도지', '순풍', '순풍', '세상', '아름답'],
#   ['우와', '비트', '대박', '발기', '장난'],
#   ['바퀴벌레',
#    '중순',
#    '월세',
#    '건물',
#    '남짓',
#    '사실',
#    '고시',
#    '원임',
#    '임차인',
#    '친척',
#    '명의',
#    '계약',
#    '세입자',
#    '친척',
#    '그거',
#    '주일',
#    '하루',
#    '시간',
#    '월급',
#    '입주',
#    '세탁기',
#    '수도',
#    '바퀴벌레',
#    '보이',
#    '시작',
#    '소장',
#    '반응',
#    '바퀴벌레',
#    '수도',
#    '세탁기',
#    '아무',
#    '얼굴',
#    '바퀴벌레',
#    '떨어지',
#    '허벅지',
#    '바퀴벌레',
#    '사체',
#    '그래서',
#    '일부',
#    '청소',
#    '근처',
#    '모텔',
#    '하루',
#    '맞음',
#    '일부',
#    '청소',
#    '자기',
#    '원래',
#    '주인',
#    '따',
#    '친척',
#    '주인',
#    '연락처',
#    '인지',
#    '지금',
#    '의문',
#    '주인',
#    '월세',
#    '도중',
#    '방역',
#    '업체',
#    '비용',
#    '요구',
#    '수정',
#    '부탁',
#    '세탁기',
#    '매일',
#    '인방',
#    '살인',
#    '충동',
#    '친척',
#    '이랑',
#    '이야기',
#    '이사',
#    '합의',
#    '이때',
#    '이사',
#    '계약',
#    '하루',
#    '탈출',
#    '근데',
#    '주인',
#    '월세',
#    '만기',
#    '기간',
#    '주인',
#    '맞음',
#    '친척',
#    '자기',
#    '신경',
#    '그렇',
#    '이사',
#    '주인',
#    '이야기',
#    '자체',
#    '세입자',
#    '구하',
#    '안구',
#    '친척',
#    '만기일',
#    '월세',
#    '내래',
#    '현재',
#    '청소',
#    '폐기물',
#    '정리',
#    '견적',
#    '퇴실',
#    '벽지',
#    '청소',
#    '계약서',
#    '월세',
#    '관리비',
#    '나감',
#    '결국',
#    '현재',
#    '퇴실',
#    '매달',
#    '월세',
#    '관리비',
#    '포함',
#    '퇴실',
#    '월세',
#    '기본',
#    '관리비',
#    '만기일',
#    '개월',
#    '대충',
#    '손해',
#    '비용',
#    '정도',
#    '억울',
#    '주일',
#    '근무',
#    '억울',
#    '원룸',
#    '짜리',
#    '쓰레기',
#    '계약',
#    '억울',
#    '이야기',
#    '원래',
#    '평이',
#    '이사',
#    '요구',
#    '주인',
#    '억울',
#    '억울'],
#   ['도지'],
#   ['도지', '대가리'],
#   ['호떡', '어도', '호떡', '어도'],
#   [],
#   ['마스크', '도지', '조롱', '새끼', '제일'],
#   ['종전', '리얼'],
#   ['시간', '지금', '미친개', '하루', '이틀', '오늘', '그날'],
#   ...]]
